# %% [markdown]
# # Intro to Natural Language Processing (NLP)
#
# The Natural Language Processing (NLP) field is incredibly vast, and it has applications in virtually every aspect of data science. In this notebook, we will walk through a **very brief** survey of NLP, and provide some instruction on a couple handy tools along the way.
#
# NLP tools span a wide range of implementations, and it is not uncommon for NLP packages to have conflicts with other Python libraries. So, to keep everything compatible in one place, it is recommended that you create a new pip environment for NLP projects. To set up an NLP pip environment for this lab, follow the steps in the "Pip Environment" section of the [Python Environment Setup page in Canvas](https://iu.instructure.com/courses/2181786/pages/week-1-%7C-python-environment-setup?module_item_id=30340853), and **use the *environment.yml* file provided in this folder.** This should install the packages you'll need for this lab.
#
# Next, **[download a spaCy NLP model](https://spacy.io/models)** based on your preferences (in the NLP environment) so you can use the spaCy library installed in the environment.
#
# *Optionally, if you prefer to use a different environment, install the following packages separately using pip: [Scikit-Learn](https://scikit-learn.org/stable/install.html#installing-the-latest-release), [spaCy](https://spacy.io/usage), [ScatterText](https://github.com/JasonKessler/scattertext#installation), [CorEx](https://ryanjgallagher.github.io/code/corex/example), and [vaderSentiment](https://github.com/cjhutto/vaderSentiment#installation).*

# %% [markdown]
# ## Preprocessing
#
# To illustrate preprocessing text data, we'll use the [spaCy](https://spacy.io/) package.
#
# *spaCy is capable of **much** more than what we will use it for in this lab. More advanced implementations of spaCy may require knowledge outside the scope of this course.*

# %%
import pandas as pd
import spacy
from spacy import displacy
print(spacy.__version__)
# Out:
# 3.7.4

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
# %config InlineBackend.figure_formats = ['svg']

# %% [markdown]
# ### Tokenizing
#
# The very first part of dealing with text data is to collect each **term** or unitary element of text (e.g., words, punctuation, etc.) in the form of "tokens".

# %%
# depends on your choice of spaCy model
nlp = spacy.load('en_core_web_sm')

# %%
intro = '''The Natural Language Processing (NLP) field is incredibly vast,
and it has applications in virtually every aspect of data science.
In this notebook, we will walk through a **very brief** survey of NLP,
and provide some instruction on a couple handy tools along the way.
'''

doc = nlp(intro)

# %%
print([t.text for t in doc])
# Out:
# ['The', 'Natural', 'Language', 'Processing', '(', 'NLP', ')', 'field', 'is', 'incredibly', 'vast', ',', '\n', 'and', 'it', 'has', 'applications', 'in', 'virtually', 'every', 'aspect', 'of', 'data', 'science', '.', '\n', 'In', 'this', 'notebook', ',', 'we', 'will', 'walk', 'through', 'a', '*', '*', 'very', 'brief', '*', '*', 'survey', 'of', 'NLP', ',', '\n', 'and', 'provide', 'some', 'instruction', 'on', 'a', 'couple', 'handy', 'tools', 'along', 'the', 'way', '.', '\n']

# %%
for i, sentence in enumerate(doc.sents):
    print(f"sentence {i+1}\n\n", sentence)
# Out:
# sentence 1
#
#  The Natural Language Processing (NLP) field is incredibly vast,
# and it has applications in virtually every aspect of data science.
#
# sentence 2
#
#  In this notebook, we will walk through a **very brief** survey of NLP,
# and provide some instruction on a couple handy tools along the way.

# %%
df_intro = []

for token in doc:
    df_intro.append([
        token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
        token.shape_, token.is_alpha, token.is_stop
    ])

# %%
df_intro = pd.DataFrame(columns=["text", "lemma_", "pos_", "tag_", "dep_", "shape_", "is_alpha", "is_stop"],
                        data=df_intro)

# %%
df_intro.sample(5)
# Out:
#        text   lemma_   pos_ tag_  dep_ shape_  is_alpha  is_stop
# 43      NLP      NLP  PROPN  NNP  pobj    XXX      True    False
# 46      and      and  CCONJ   CC    cc    xxx      True     True
# 0       The      the    DET   DT   det    Xxx      True     True
# 23  science  science   NOUN   NN  pobj   xxxx      True    False
# 15      has     have   VERB  VBZ  conj    xxx      True     True

# %% [markdown]
# What is a **stop word**?

# %%
df_intro[df_intro['is_stop']].sample(10)
# Out:
#      text lemma_  pos_ tag_      dep_ shape_  is_alpha  is_stop
# 42     of     of   ADP   IN      prep     xx      True     True
# 51      a      a   DET   DT  quantmod      x      True     True
# 50     on     on   ADP   IN      prep     xx      True     True
# 26     In     in   ADP   IN      prep     Xx      True     True
# 31   will   will   AUX   MD       aux   xxxx      True     True
# 27   this   this   DET   DT       det   xxxx      True     True
# 0     The    the   DET   DT       det    Xxx      True     True
# 19  every  every  PRON   DT    nummod   xxxx      True     True
# 55  along  along   ADP   IN      prep   xxxx      True     True
# 37   very   very   ADV   RB    advmod   xxxx      True     True

# %% [markdown]
# spaCy defines **lemmas** to be *"the base forms of words. For example, the lemma of `was` is `be`, and the lemma of `rats` is `rat`."*

# %%
t = nlp('running')[0]
t.lemma_
# Out:
# 'run'

# %% [markdown]
# **Sentence Dependencies**

# %% [markdown]
# We can visualize some of these attributes (like the sentence dependencies) using [displacy](https://spacy.io/usage/visualizers).

# %%
doc = nlp('We can visualize these using displacy.')

# %%
displacy.render(doc, style='dep', options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e80523cfb101488ab5eb3a6b7da06c95-0" class="displacy" width="770" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">We</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">visualize</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">these</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">using</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">displacy.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e80523cfb101488ab5eb3a6b7da06c95-0-0" stroke-width="2px" d="M70,182.0 C70,62.0 285.0,62.0 285.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e80523cfb101488ab5eb3a6b7da06c95-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e80523cfb101488ab5eb3a6b7da06c95-0-1" stroke-width="2px" d="M190,182.0 C190,122.0 280.0,122.0 280.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e80523cfb101488ab5eb3a6b7da06c95-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,184.0 L182,172.0 198,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e80523cfb101488ab5eb3a6b7da06c95-0-2" stroke-width="2px" d="M430,182.0 C430,62.0 645.0,62.0 645.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e80523cfb101488ab5eb3a6b7da06c95-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,184.0 L422,172.0 438,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e80523cfb101488ab5eb3a6b7da06c95-0-3" stroke-width="2px" d="M550,182.0 C550,122.0 640.0,122.0 640.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e80523cfb101488ab5eb3a6b7da06c95-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,184.0 L542,172.0 558,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e80523cfb101488ab5eb3a6b7da06c95-0-4" stroke-width="2px" d="M310,182.0 C310,2.0 650.0,2.0 650.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e80523cfb101488ab5eb3a6b7da06c95-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M650.0,184.0 L658.0,172.0 642.0,172.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# Note: this isn't always going to be *exactly* accurate, but it's very good and still useful.

# %% [markdown]
# ### Named Entity Recognition
#
# Some words are **Named Entities**: locations like "Alaska", dates like "January 1st", companies like "Google", etc. spaCy can tag these using [Named Entity Recognition](https://spacy.io/usage/linguistic-features#named-entities).

# %%
doc = nlp('... locations like "Alaska", dates like "January 1st", companies like "Google", etc.')

# %%
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">... locations like &quot;
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alaska
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# &quot;, dates like &quot;
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     January 1st
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# &quot;, companies like &quot;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# &quot;, etc.</div></span>

# %% [markdown]
# ### Multiple Documents
#
# *NLP Terms: A **document** is a collection of **tokens**, and a **corpus** is a collection of documents.*
#
# When spaCy processes text, it runs it through a [pipeline](https://spacy.io/usage/processing-pipelines) of different models to store token attributes for each token. This is how we get the functionality above. Though, when we are tokenizing multiple documents, we might not need all of these [built-in components](https://spacy.io/usage/processing-pipelines#built-in). For example, we might just need enough to filter our text based on the analysis done.
#
# For example, suppose we've determined that we want to the remove the following tokens from a dataset of [coffee reviews](https://www.kaggle.com/datasets/schmoyote/coffee-reviews-dataset/) (descriptions):
#
# - stop words (except the lemma "not", to maintain the idea of object negation)
# - punctuation
# - numbers
#
# In this case, we don't need NER, Dependency Labels, or Document Labels. Removing these processes from the spaCy pipeline will save us some time.

# %%
df_coffee = pd.read_csv('./data/coffee_analysis.csv')

# %%
df_coffee.drop_duplicates(subset='desc_1', inplace=True)

# %%
df_coffee.shape
# Out:
# (2092, 12)

# %%
print(df_coffee['desc_1'].sample().iloc[0])
# Out:
# Spice-toned, exceptionally sweet. Clove, cinnamon, green apple, cocoa nib, magnolia in aroma and cup. Crisply sweet structure with lively acidity; very full, syrupy mouthfeel. The finish consolidates to spice-toned cocoa nib with a hint of magnolia.

# %%
# nlp.pipe returns a generator
docs = nlp.pipe(df_coffee['desc_1'], disable=['ner', 'parser', 'textcat'])

# save the spaCy objects into the DataFrame
df_coffee['spacy_doc'] = list(docs)

# %%
def tokenizer(doc, join_tokens=False):
    '''
    Tokenize a single spaCy `doc`.

    join_tokens : bool
        Whether we want to return a list of strings or
        a list of lists. If True, join with space (" ").
    '''

    # collect lemmas that meet the following criteria:
    tokens = [w.lemma_.lower() for w in doc if
              (not w.is_stop
               and not w.is_punct
               and not w.like_num) \
              or (w.lemma_ == 'not')]

    if join_tokens:
        return ' '.join(tokens)
    else:
        return tokens

# %%
df_coffee['docs_clean'] = df_coffee['spacy_doc'].apply(tokenizer)

# %%
df_coffee[['desc_1', 'spacy_doc', 'docs_clean']].head()
# Out:
#                                               desc_1  \
# 0  Evaluated as espresso. Sweet-toned, deeply ric...
# 1  Evaluated as espresso. Sweetly tart, floral-to...
# 2  Crisply sweet, cocoa-toned. Lemon blossom, roa...
# 3  Delicate, sweetly spice-toned. Pink peppercorn...
# 4  Deeply sweet, subtly pungent. Honey, pear, tan...
#
#                                            spacy_doc  \
# 0  (Evaluated, as, espresso, ., Sweet, -, toned, ...
# 1  (Evaluated, as, espresso, ., Sweetly, tart, ,,...
# 2  (Crisply, sweet, ,, cocoa, -, toned, ., Lemon,...
# 3  (Delicate, ,, sweetly, spice, -, toned, ., Pin...
# 4  (Deeply, sweet, ,, subtly, pungent, ., Honey, ...
#
#                                           docs_clean
# 0  [evaluate, espresso, sweet, tone, deeply, rich...
# 1  [evaluate, espresso, sweetly, tart, floral, to...
# 2  [crisply, sweet, cocoa, tone, lemon, blossom, ...
# 3  [delicate, sweetly, spice, tone, pink, pepperc...
# 4  [deeply, sweet, subtly, pungent, honey, pear, ...

# %%
print(df_coffee['desc_1'].iloc[5])
# Out:
# Delicate, richly and sweetly tart. Dried hibiscus, fine musk, almond, sandalwood, raspberry in aroma and cup. Fruit-toned, deeply sweet structure with gently-expressed acidity; buoyant, satiny-smooth mouthfeel. The crisp, flavor-saturated finish is characterized by sweet-tart fruit and floral tones (raspberry, hibiscus).

# %%
print(df_coffee['docs_clean'].iloc[5])
# Out:
# ['delicate', 'richly', 'sweetly', 'tart', 'dry', 'hibiscus', 'fine', 'musk', 'almond', 'sandalwood', 'raspberry', 'aroma', 'cup', 'fruit', 'tone', 'deeply', 'sweet', 'structure', 'gently', 'express', 'acidity', 'buoyant', 'satiny', 'smooth', 'mouthfeel', 'crisp', 'flavor', 'saturate', 'finish', 'characterize', 'sweet', 'tart', 'fruit', 'floral', 'tone', 'raspberry', 'hibiscus']

# %% [markdown]
# ## Vectorization
#
# Once we have our tokens selected and "cleaned", we need to convert the textual data into numerical data. **In other words, we need to convert each token (or document) into a *vector* representation.** There are many ways to represent textual information in the form of numerical data, but in this class we will cover Count Vectorization and Term-Frequency Inverse Document Frequency Vectorization; we'll call these **vectorizers**.

# %% [markdown]
# ### Brief Intro to Scikit-Learn
#
# **[Scikit-Learn](https://scikit-learn.org/stable/index.html) is the industry standard data science toolkit**, and it's modules are used in almost every aspect of data science. Here, we are going to use its [feature extraction module](https://scikit-learn.org/stable/modules/feature_extraction.html), which is built for extracting numerical features from data such as text or images. We will be using it for vectorization of text data, and in these cases, the scikit-learn process is:
#
# 1. Preprocess some data (e.g., from text to tokens)
# 2. Define a model (e.g., a vectorizer)
# 3. "Fit" that model to the data using `.fit`
# 4. Transform the data based on the model's parameters using `.transform`
#     - We can also combine these last two steps with `.fit_transform`

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %% [markdown]
# ### CountVectorizer
#
# CountVectorizer converts each document into a "Bag of Words". In other words, the document is encoded based on the words it contains, **regardless of the order**. And, each term can be represented based on the documents it is contained in.

# %%
corpus_raw = ['This coffee is really really tasty.',
              'Tea smells and tastes better than coffee.',
              "Best smelling coffee I have ever smelled!"]

# %%
cv = CountVectorizer(ngram_range=(1, 1),  # capture "pairs", or "n-tuples" of adjacent words
                     max_df=1.0,          # exclude terms in ≥ `max_df` (or %) of docs
                     min_df=1,            # exclude terms in ≤ `min_df` (or %) of docs
                     max_features=None,   # maximum number of terms/ngrams to include
                     binary=False)        # only log 1s and 0s for term presence

X = cv.fit_transform(corpus_raw)

df = pd.DataFrame(X.toarray(),
                  index=corpus_raw,
                  columns=cv.get_feature_names_out())

# %%
plt.figure(figsize=(8, 1))
g = sns.heatmap(df, cmap='Blues', annot=True, cbar=False, linewidths=1)

# %% [markdown]
# This is called a **document-term matrix**.
#
# - We could use `max_df` to remove the term "coffee" since it occurs in every document. This is one example of extracting *informative* features from text; i.e., the term "coffee" doesn't provide new information for each document.
# - Also, we can already see that some of these words give us more information than others. For example, "smelling" and "smells" mean roughly the same thing, and "had"/"have" aren't really necessary for understanding reviews.
#
# This is why we use the filtering in spaCy.

# %%
docs = nlp.pipe(corpus_raw)
corpus_clean = [tokenizer(d, True) for d in docs]
corpus_clean
# Out:
# ['coffee tasty', 'tea smell taste well coffee', 'good smell coffee smell']

# %%
cv = CountVectorizer(ngram_range=(1, 1),
                     max_df=0.9,
                     min_df=1,
                     max_features=None,
                     binary=False)

X = cv.fit_transform(corpus_clean)

df = pd.DataFrame(X.toarray(),
                  index=corpus_raw,
                  columns=cv.get_feature_names_out())

# %%
plt.figure(figsize=(6, 1))
g = sns.heatmap(df, cmap='Blues', annot=True, cbar=False, linewidths=1)

# %%
cv = CountVectorizer(ngram_range=(2, 2),  # use (1, 2) for unigrams *and* bigrams
                     max_df=0.9,
                     min_df=1,
                     max_features=None,
                     binary=False)

X = cv.fit_transform(corpus_clean)

df = pd.DataFrame(X.toarray(),
                  index=corpus_clean,
                  columns=cv.get_feature_names_out())

# %%
plt.figure(figsize=(10, 1))
g = sns.heatmap(df, cmap='Blues', annot=True, cbar=False, linewidths=1)

# %% [markdown]
# Now these vectors are a bit more meaningful. Notice, in a way, bigrams are a contrived way to capture context in textual data.

# %% [markdown]
# ### TFIDF Vectorizer
#
# Downsides of Count Vectorizer:
#
# - Counts can be too simplistic
# - High counts can dominate, especially for high frequency words or long documents
# - Each word is treated equally, when some terms might be more "important" than others
#
# We define TFIDF as:
#
# $$
# \text{TF-IDF} = \text{term frequency} * \text{inverse document frequency}
# $$
#
# where:
#
# $$
# \begin{align*}
# \text{term frequency} &= \frac{\text{term count in document}}{\text{total terms in document}} \\[8pt]
# \text{inverse document frequency} &= \log\bigg(\frac{\text{total number of documents} + 1}{\text{number of documents with term} + 1}\bigg)
# \end{align*}
# $$

# %% [markdown]
# This measure is calculated for every term-document combination:
#
# - The **term frequency** measures the "density" of a word in a document
# - The **inverse document frequency** (without the $\log$) measures the size of the corpus *in terms of* the number of documents containing the term. E.g., if IDF=5 then the corpus is 5 times the size of the "sub-corpus" of documents containing the term. The $\log$ dampens the effect of the inverse document frequency as the denominator gets very small or the numerator gets very large.
#
# So, we can think of TF as the "main" measure, and IDF as the "scaling" factor:
#
# - Very common words across all documents will get a lower score.
# - Rare words considering all documents get a higher score.

# %%
cv = TfidfVectorizer(max_df=1.0,
                     min_df=1,
                     max_features=None)

X = cv.fit_transform(corpus_clean)

df = pd.DataFrame(X.toarray(),
                  index=corpus_clean,
                  columns=cv.get_feature_names_out())

# %%
sns.heatmap(df, square=True, cmap='Blues', annot=True, cbar=False);

# %% [markdown]
# ## Topic Modeling
#
# ### Matrix Decomposition
#
# The document term matrix $X$ is a matrix just like any other in Linear Algebra. Just so, it defines a row space (the documents represented as linear combinations of terms), and column space (terms represented as a linear combination of documents). With this, there are a few matrix decomposition methods we can use to extract further information about these documents and terms.

# %%
from sklearn.decomposition import TruncatedSVD, NMF, PCA

# %% [markdown]
# ### Singular Value Decomposition
#
# Singular Value Decomposition is a guaranteed decomposition for any rectangular matrix. It creates the following equality:
#
# $$
# X = U\Sigma V^\top
# $$
#
# **Breifly**:
# - Each row of $U$ represents the corresponding document in terms of "topics directions" along the columns.
# - The rows of $V$ (columns of $V^\top$) represent similarly represented version of the terms.
# - The $\Sigma$ matrix contains the "variance explained" by each of these topics, sorted in descending order.
#
# As far as naming goes:
#
# - The analysis of these resulting matrices is called **Principal Components Analysis (PCA)**.
# - When used with text data, this analysis is called **Latent Semantic Analysis (LSA)**.

# %%
# we need a list/array of strings to vectorize
corpus = df_coffee['spacy_doc'].apply(tokenizer, args={'join_tokens':True})

# %%
corpus.shape
# Out:
# (2092,)

# %%
cv = TfidfVectorizer(max_df=0.9,
                     min_df=0.1,
                     max_features=None)

X = cv.fit_transform(corpus)
# df = pd.DataFrame(X, index=corpus, columns=cv.get_feature_names_out())

# %%
X.shape
# Out:
# (2092, 65)

# %% [markdown]
# Note, we use `TruncatedSVD` here because it's a more efficient implementation of SVD. PCA centers the data before running the algorithm, which is more "appropriate" but takes more time. This does cause a few inconsistencies in the "sorted" $\Sigma$.

# %%
lsa = TruncatedSVD(n_components=5)  # results only change for larger (unseen) values

doc_topic = lsa.fit_transform(X)
lsa.explained_variance_ratio_
# Out:
# array([0.00488089, 0.08197356, 0.04778023, 0.04678245, 0.0350113 ])

# %%
doc_topic = pd.DataFrame(doc_topic.round(3),
                         index=df_coffee['desc_1'])
# doc_topic.head()

# %%
topic = 1
n_docs = 5

print(f"Top Documents for topic {topic}:\n")

for doc in doc_topic[topic].abs().sort_values(ascending=False).iloc[:n_docs].index:
    print(doc, '\n')
# Out:
# Top Documents for topic 1:
#
# Sweetly floral and delicately cocoa-toned. Honeysuckle, cocoa nib, Concord grape, agave, lemon-thyme in aroma and cup. High-toned structure with juicy, confident acidity; buoyant, lively, viscous mouthfeel. Honeysuckle and cocoa nib characterize the sweet finish.
#
# Evaluated as espresso. Roast-rounded, chocolaty. Dark chocolate, gardenia, gently scorched cedar, molasses, prune in aroma and small cup. Viscous, creamy mouthfeel; chocolaty, slightly smoky finish. In three parts milk, floral and chocolate notes preside.
#
# Evaluated as espresso. Fruit-forward, chocolaty. Dark chocolate, black cherry, lily, molasses, cedar in aroma and small cup. Very syrupy mouthfeel; crisp, chocolaty finish. In three parts milk, dark chocolate notes take center stage, supported by notes of black cherry and lily.
#
# Evaluated as espresso. Bittersweet, richly pungent, chocolaty and floral. Dark chocolate, plum, cedar, magnolia in aroma and small cup. Plump, satiny mouthfeel; bittersweet and chocolaty in the finish. Chocolate and flowers dominate in three parts milk.
#
# Delicately sweet-tart, floral-toned. Narcissus, apricot, cocoa nib, lemon verbena, frankincense in aroma and cup. Sweet-tart structure with delicately juicy acidity; very full, syrupy mouthfeel. Cocoa nib and narcissus focus the long, lingering finish.

# %%
topic_term = pd.DataFrame(lsa.components_.round(3),
                          columns = cv.get_feature_names_out())

topic_term
# Out:
#    acidity  almond   bake  balanced  bright  brisk  butter  cedar  center  \
# 0    0.192   0.124  0.090     0.103   0.117  0.072   0.068  0.167   0.082
# 1    0.072  -0.025 -0.142     0.065   0.120 -0.019  -0.019 -0.107  -0.003
# 2    0.039   0.060  0.301    -0.047  -0.127  0.194   0.059  0.142  -0.007
# 3   -0.120   0.010 -0.112    -0.007   0.008 -0.086   0.032  0.063  -0.012
# 4   -0.085  -0.149 -0.124     0.016  -0.166 -0.025  -0.081 -0.083  -0.063
#
#    chocolate  ...  sweet  sweetly  syrup  syrupy   tart   tone  undertone  \
# 0      0.256  ...  0.280    0.146  0.079   0.144  0.195  0.249      0.077
# 1     -0.461  ...  0.034    0.029  0.041   0.038  0.113  0.032     -0.016
# 2     -0.070  ...  0.098   -0.057  0.059  -0.149 -0.107  0.111      0.058
# 3     -0.028  ... -0.173   -0.039 -0.047  -0.042  0.032  0.098      0.005
# 4     -0.068  ...  0.084   -0.143 -0.057   0.041 -0.365 -0.077      0.034
#
#    velvety  vibrant   zest
# 0    0.070    0.066  0.148
# 1   -0.046    0.070  0.040
# 2    0.126   -0.089  0.014
# 3   -0.015   -0.017  0.006
# 4    0.020   -0.053 -0.077
#
# [5 rows x 65 columns]

# %%
# the third "topic"
topic = 2
n_terms = 10

topic_term.T[topic].abs().sort_values(ascending=False).iloc[:n_terms]
# Out:
# bake          0.301
# sandalwood    0.262
# dark          0.256
# nut           0.238
# flavor        0.219
# savory        0.212
# juicy         0.206
# cut           0.200
# hazelnut      0.197
# brisk         0.194
# Name: 2, dtype: float64

# %% [markdown]
# ### Non-Negative Matrix Factorization
#
# [NMF](https://en.wikipedia.org/wiki/Non-negative_matrix_factorization) is very similar to SVD. Here, we have the following decomposition.
#
# $$
# X = WH
# $$
#
# In this case though, all values in $W$ and $H$ are positive, and we can *approximate* this decomposition because all values in $X$ are positive.

# %%
nmf = NMF(4)  # here, the number will change the results
doc_topic = nmf.fit_transform(X)

# %%
doc_topic = pd.DataFrame(doc_topic.round(3),
                         index=df_coffee['desc_1'])
# doc_topic.head()

# %%
topic = 1
n_docs = 5

print(f"Top Documents for topic {topic}:\n")

for doc in doc_topic[topic].abs().sort_values(ascending=False).iloc[:n_docs].index:
    print(doc, '\n')
# Out:
# Top Documents for topic 1:
#
# Evaluated as espresso. Fruit-forward, chocolaty. Dark chocolate, black cherry, lily, molasses, cedar in aroma and small cup. Very syrupy mouthfeel; crisp, chocolaty finish. In three parts milk, dark chocolate notes take center stage, supported by notes of black cherry and lily.
#
# Evaluated as espresso. Bittersweet, richly pungent, chocolaty and floral. Dark chocolate, plum, cedar, magnolia in aroma and small cup. Plump, satiny mouthfeel; bittersweet and chocolaty in the finish. Chocolate and flowers dominate in three parts milk.
#
# Evaluated as espresso. Deeply chocolaty, balanced, roast-rounded. Dark chocolate, nectarine, molasses, gently scorched cedar, rhododendron in aroma and small cup. Full, satiny mouthfeel; crisp, chocolaty finish. In three parts milk the dark chocolate notes are amplified, as are the florals
#
# Evaluated as espresso. Roast-rounded, chocolaty. Dark chocolate, gardenia, gently scorched cedar, molasses, prune in aroma and small cup. Viscous, creamy mouthfeel; chocolaty, slightly smoky finish. In three parts milk, floral and chocolate notes preside.
#
# Evaluated as espresso. Richly chocolaty, fruit-toned. Dark chocolate, raspberry jam, cedar, caramel, lemon verbena in aroma and small cup. Crisp, syrupy-smooth mouthfeel; chocolaty, sweetly herbaceous finish. In three parts milk, raspberry notes recede and caramel and chocolate come forward.

# %%
topic_term = pd.DataFrame(nmf.components_.round(3),
                          columns = cv.get_feature_names_out())

topic_term
# Out:
#    acidity  almond   bake  balanced  bright  brisk  butter  cedar  center  \
# 0    0.933   0.391  0.000     0.612   0.863  0.000   0.083  0.022   0.351
# 1    0.000   0.173  0.000     0.047   0.000  0.000   0.133  0.603   0.114
# 2    0.547   0.485  0.961     0.104   0.000  0.611   0.301  0.660   0.210
# 3    0.492   0.163  0.000     0.364   0.487  0.017   0.112  0.284   0.167
#
#    chocolate  ...  sweet  sweetly  syrup  syrupy   tart   tone  undertone  \
# 0      0.805  ...  1.422    0.898  0.233   1.220  0.997  0.601      0.091
# 1      1.579  ...  0.029    0.135  0.000   0.174  0.178  0.398      0.179
# 2      0.709  ...  0.897    0.238  0.294   0.032  0.199  0.702      0.276
# 3      0.000  ...  0.504    0.334  0.230   0.309  0.706  0.738      0.192
#
#    velvety  vibrant   zest
# 0    0.000    0.556  0.650
# 1    0.118    0.000  0.136
# 2    0.438    0.000  0.353
# 3    0.048    0.261  0.377
#
# [4 rows x 65 columns]

# %%
topic = 0
n_terms = 10

topic_term.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# savory        2.345
# sweet         1.422
# long          1.284
# flavor        1.231
# syrupy        1.220
# juicy         1.121
# sandalwood    1.120
# structure     1.107
# resonant      1.047
# richly        1.022
# Name: 0, dtype: float64

# %%
topic = 1
n_terms = 10

topic_term.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# chocolate    1.579
# dark         1.305
# milk         1.131
# espresso     1.127
# evaluate     1.099
# small        1.097
# chocolaty    1.015
# cedar        0.603
# fruit        0.521
# floral       0.493
# Name: 1, dtype: float64

# %% [markdown]
# As you can tell, this often produces more agreeable results than LSA.

# %% [markdown]
# ### Latent Dirichlet Allocation (LDA)
#
# [LDA](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.LatentDirichletAllocation.html) is a "generative" model that builds topics with the assumption that documents are generated based on a probability distribution of topics, and that topics are just a probability distribution of terms.

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
# these parameters usually require a good bit of tuning ...
lda = LatentDirichletAllocation(n_components=5,
                                max_iter=50)

X_topics = lda.fit_transform(X)

# %%
df_lda = pd.DataFrame(data = X_topics,
                      index = corpus)

# %%
topic = 0
n_docs = 3

for d in df_lda[topic].sort_values(ascending=False).iloc[:n_docs].index:
    print(d, '\n')
# Out:
# richly sweet fruit forward dried apricot cocoa nib star jasmine almond maple syrup aroma cup sweetly tart structure bright juicy acidity crisp syrupy mouthfeel long linger finish center dry apricot cocoa note support cedar like wood
#
# balanced richly sweet spice tone apricot cocoa nib lilac coriander amber aroma cup deep sweet savory structure bright acidity syrupy smooth mouthfeel finish crisp juicy lead note apricot coriander short rich cocoa tone floral long
#
# crisp bright richly sweet savory wild honey black cherry lemon verbena hazelnut rhododendron like flower aroma cup balanced vivid structure sweetly tart juicy acidity buoyant silky mouthfeel resonant rich finish cocoa surface alongside note wild honey black cherry short vanilla like floral long

# %%
topic = 1
n_docs = 3

for d in df_lda[topic].sort_values(ascending=False).iloc[:n_docs].index:
    print(d, '\n')
# Out:
# deeply sweet richly nut tone hazelnut butter magnolia like flower crisp pear cedar agave syrup aroma cup sweet structure gentle round acidity syrupy smooth mouthfeel finish consolidate deep nut rich aromatic wood
#
# crisply sweet fruit tone raspberry fresh cut fir maple syrup cocoa powder freesia like flower aroma cup sweet structure brisk acidity satiny smooth mouthfeel gently dry finish center quiet note raspberry fir
#
# richly sweet tart deeply berry tone fresh blueberry rhododendron meyer lemon zest dark chocolate fresh cut oak aroma cup sweet tone structure gentle round acidity syrupy smooth mouthfeel finish consolidate note blueberry dark chocolate oak undertone

# %%
df_lda_terms = pd.DataFrame(data = lda.components_,
                            columns = cv.get_feature_names_out())

# %%
topic = 0
n_terms = 10

df_lda_terms.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# cocoa        177.924218
# nib          148.044301
# tart          80.952703
# sweet         75.988030
# tone          75.715614
# acidity       62.648296
# bright        60.305264
# juicy         58.050948
# structure     56.808316
# lemon         53.190068
# Name: 0, dtype: float64

# %%
topic = 1
n_terms = 10

df_lda_terms.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# bake         91.756531
# sweet        80.865569
# chocolate    71.517809
# hazelnut     68.027138
# tone         65.769915
# fresh        62.004350
# nut          59.923083
# oak          57.302193
# cut          56.396061
# acidity      55.448612
# Name: 1, dtype: float64

# %% [markdown]
# ### Anchored Correlation Explanation (CorEx)
#
# [CorEx](https://github.com/gregversteeg/corex_topic) is a discriminative model, which starts from $X$ (documents/words) to determine $Y$ (topics). CorEx looks for groups of words that are in the same topic, a.k.a. have high Total Correlation (TC), or convey the same information.
#
# - If words are **tightly related** (always appear together in the same topic/document), TC will be high. This is a good topic.
# - If the words are all **independent** (never appear together in the same document or topic), TC = 0. This is a bad topic.
# - CorEx creates a partition across terms. I.e., **terms can only occur in a single topic**.
#
# CorEx roughly follows this algorithm:
# 1. Look for a group of words that are both as broad (in many documents) and overlapping as possible (both together will lead to high TC), and call this a topic.
# 2. Repeat the process for another set of words (not overlapping with your previous group) with as high a TC as possible, and call this the next topic.
#
# As we create more topics, each subsequent topic will have lower TC.

# %%
from corextopic import corextopic as ct

# %%
# CorEx requires count data
cv = CountVectorizer(max_df=0.9,
                     min_df=0.1,
                     max_features=None)

X = cv.fit_transform(corpus)

# %%
topic_model = ct.Corex(n_hidden=5,                        # number of topics
                       words=cv.get_feature_names_out(),  # list of terms in corpus
                       seed=1)

doc_topic = topic_model.fit_transform(X, words=cv.get_feature_names_out(), docs=corpus)

# %%
# Print all topics from the CorEx topic model
topics = topic_model.get_topics()

for n, topic in enumerate(topics):
    topic_words,_,_ = zip(*topic)
    print(f"{n}: " + ','.join(topic_words))
# Out:
# 0: espresso,evaluate,small,milk,structure,acidity,consolidate,floral,syrup,crisp
# 1: chocolate,dark,nib,cocoa,chocolaty,bake,delicate,lemon,deep,zest
# 2: juicy,cut,gentle,bright,fresh,sandalwood,brisk,tart,high,nut
# 3: short,long,lead,undertone,rich,center,almond
# 4: sweet,sweetly,savory,deeply,fruit,smooth

# %% [markdown]
# Take a look at how you can use [anchor words](https://github.com/gregversteeg/corex_topic/tree/master#using-anchor-words) to guide the topic creation.

# %% [markdown]
# ## ScatterText
#
# Scattertext is great for
# - Visually inspecting text
# - Comparing/Contrasting corpora
# - And more...
#
# Check out Jason Kessler's GitHub project for more information: [here](https://github.com/JasonKessler/scattertext).

# %%
import scattertext as st

# %%
convention_df = st.SampleCorpora.ConventionData2012.get_data()

# %%
convention_df.head()
# Out:
#       party                                               text         speaker
# 0  democrat  Thank you. Thank you. Thank you. Thank you so ...    BARACK OBAMA
# 1  democrat  Thank you so much. Tonight, I am so thrilled a...  MICHELLE OBAMA
# 2  democrat  Thank you. It is a singular honor to be here t...  RICHARD DURBIN
# 3  democrat  Hey, Delaware. \nAnd my favorite Democrat, Jil...    JOSEPH BIDEN
# 4  democrat  Hello. \nThank you, Angie. I'm so proud of how...      JILL BIDEN

# %%
corpus = st.CorpusFromPandas(convention_df,
                             category_col='party',
                             text_col='text',
                             nlp=st.whitespace_nlp_with_sentences
                            ).build()

# %%
html = st.produce_scattertext_explorer(
        corpus,
        category='democrat',
        category_name='Democratic',
        not_category_name='Republican',
        minimum_term_frequency=10,
        pmi_threshold_coefficient=5,
        width_in_pixels=1000,
        metadata=convention_df['speaker'],
        )

# %%
with open('demo.html', 'wb') as f:
    f.write(html.encode('utf-8'))

# %% [markdown]
# ## Sentiment Analysis with VADER
#
# According to the documentation:
#
#     VADER (Valence Aware Dictionary and sEntiment Reasoner) is a lexicon and rule-based sentiment analysis tool that is specifically attuned to sentiments expressed in social media. [...]
#
#     Sentiment ratings from 10 independent human raters (all pre-screened, trained, and quality checked for optimal inter-rater reliability). Over 9,000 token features were rated on a scale from "[–4] Extremely Negative" to "[4] Extremely Positive", with allowance for "[0] Neutral (or Neither, N/A)".

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
sentences = ["VADER is smart, handsome, and funny.",  # positive sentence example
             "VADER is smart, handsome, and funny!",  # punctuation emphasis handled correctly (sentiment intensity adjusted)
             "VADER is very smart, handsome, and funny.", # booster words handled correctly (sentiment intensity adjusted)
             "VADER is VERY SMART, handsome, and FUNNY.",  # emphasis for ALLCAPS handled
             "VADER is VERY SMART, handsome, and FUNNY!!!", # combination of signals - VADER appropriately adjusts intensity
             "VADER is VERY SMART, uber handsome, and FRIGGIN FUNNY!!!", # booster words & punctuation make this close to ceiling for score
             "VADER is not smart, handsome, nor funny.",  # negation sentence example
             "The book was good.",  # positive sentence
             "At least it isn't a horrible book.",  # negated negative sentence with contraction
             "The book was only kind of good.", # qualified positive sentence is handled correctly (intensity adjusted)
             "The plot was good, but the characters are uncompelling and the dialog is not great.", # mixed negation sentence
             "Today SUX!",  # negative slang with capitalization emphasis
             "Today only kinda sux! But I'll get by, lol", # mixed sentiment example with slang and constrastive conjunction "but"
             "Make sure you :) or :D today!",  # emoticons handled
             # "Catch utf-8 emoji such as such as 💘 and 💋 and 😁",  # emojis handled, ignored for seaborn plot below
             "Not bad at all"  # Capitalized negation
             ]

# %%
df_sentiment = []

analyzer = SentimentIntensityAnalyzer()

for sentence in sentences:
    vs = analyzer.polarity_scores(sentence)
    df_sentiment.append(vs)

# %%
df_sentiment = pd.DataFrame(df_sentiment,
                            index = sentences)

# %%
sns.heatmap(df_sentiment, cmap='Blues', annot=True, cbar=False, linewidths=1);

# %% [markdown]
# # EXERCISES

# %% [markdown]
# ## Exercise 1
#
# Using a book from [Project Gutenberg](https://www.gutenberg.org/), get the text data directly from its URL using the `requests` package. Break the book into 50 or more sensible "chunks" like chapters or paragraphs, organizing them into a list.
#
# Load this data into a spaCy pipeline and analyze either Named Entities or Parts of Speech in each chunk.
#
# Provide your analysis: What types of entities or parts of speech are common, and what are uncommon? What insights can you draw from these patterns?
#
# *Note*: Do not download any file, make use of URL in your code.

# %%
import requests
import spacy

url = "https://www.gutenberg.org/cache/epub/36/pg36.txt"
response = requests.get(url)
text = response.text

chunks = [chunk.strip() for chunk in text.split("\n\n") if chunk.strip()]

nlp = spacy.load("en_core_web_sm")

pos_analysis = []
for chunk in chunks:
    doc = nlp(chunk)
    pos_analysis.append([(token.text, token.pos_) for token in doc])

for i, analysis in enumerate(pos_analysis):
    print(f"Chunk {i+1}:")
    for token, pos in analysis:
        print(f"    {token} ({pos})")
# Out:
# Chunk 1:
#     ﻿The (NOUN)
#     Project (PROPN)
#     Gutenberg (PROPN)
#     eBook (PROPN)
#     of (ADP)
#     The (DET)
#     War (PROPN)
#     of (ADP)
#     the (DET)
#     Worlds (PROPN)
#
#
#  (SPACE)
#     This (DET)
#     ebook (NOUN)
#     is (AUX)
#     for (ADP)
#     the (DET)
#     use (NOUN)
#     of (ADP)
#     anyone (PRON)
#     anywhere (ADV)
#     in (ADP)
#     the (DET)
#     United (PROPN)
#     States (PROPN)
#     and (CCONJ)
#
#  (SPACE)
#     most (ADJ)
#     other (ADJ)
#     parts (NOUN)
#     of (ADP)
#     the (DET)
#     world (NOUN)
#     at (ADP)
#     no (DET)
#     cost (NOUN)
#     and (CCONJ)
#     with (ADP)
#     almost (ADV)
#     no (PRON)
#     restrictions (NOUN)
#
#  (SPACE)
#     whatsoever (ADV)
#     . (PUNCT)
#     You (PRON)
#     may (AUX)
#     copy (VERB)
#     it (PRON)
#     , (PUNCT)
#     give (VERB)
#     it (PRON)
#     away (ADV)
#     or (CCONJ)
#     re (VERB)
#     - (VERB)
#     use (VERB)
#     it (PRON)
#     under (ADP)
#     the (DET)
#     terms (NOUN)
#
#  (SPACE)
#     of (ADP)
#     the (DET)
#     Project (PROPN)
#     Gutenberg (PROPN)
#     License (PROPN)
#     included (VERB)
#     with (ADP)
#     this (DET)
#     ebook (NOUN)
#     or (CCONJ)
#     online (NOUN)
#
#  (SPACE)
#     at (ADP)
#     www.gutenberg.org (NUM)
#     . (PUNCT)
#     If (SCONJ)
#     you (PRON)
#     are (AUX)
#     not (PART)
#     located (VERB)
#     in (ADP)
#     the (DET)
#     United (PROPN)
#     States (PROPN)
#     , (PUNCT)
#
#  (SPACE)
#     you (PRON)
#     will (AUX)
#     have (VERB)
#     to (PART)
#     check (VERB)
#     the (DET)
#     laws (NOUN)
#     of (ADP)
#     the (DET)
#     country (NOUN)
#     where (SCONJ)
#     you (PRON)
#     are (AUX)
#     located (VERB)
#
#  (SPACE)
#     before (ADP)
#     using (VERB)
#     this (DET)
#     eBook (PROPN)
#     . (PUNCT)
#
#
#  (SPACE)
#     Title (NOUN)
#     : (PUNCT)
#     The (DET)
#     War (PROPN)
#     of (ADP)
#     the (DET)
#     Worlds (PROPN)
#
#
#
#  (SPACE)
#     Author (PROPN)
#     : (PUNCT)
#     H. (PROPN)
#     G. (PROPN)
#     Wells (PROPN)
#
#
#  (SPACE)
#     Release (PROPN)
#     date (NOUN)
#     : (PUNCT)
#     October (PROPN)
#     1 (NUM)
#     , (PUNCT)
#     2004 (NUM)
#     [ (PUNCT)
#     eBook (VERB)
#     # (SYM)
#     36 (NUM)
#     ] (PUNCT)
#
#                  (SPACE)
#     Most (ADV)
#     recently (ADV)
#     updated (VERB)
#     : (PUNCT)
#     November (PROPN)
#     27 (NUM)
#     , (PUNCT)
#     2021 (NUM)
#
#
#  (SPACE)
#     Language (NOUN)
#     : (PUNCT)
#     English (PROPN)
#
#
#
#
#  (SPACE)
#     * (PUNCT)
#     * (PUNCT)
#     * (ADJ)
#     START (NOUN)
#     OF (ADP)
#     THE (DET)
#     PROJECT (PROPN)
#     GUTENBERG (PROPN)
#     EBOOK (VERB)
#     THE (DET)
#     WAR (PROPN)
#     OF (ADP)
#     THE (DET)
#     WORLDS (PROPN)
#     * (PUNCT)
#     * (PUNCT)
#     * (PUNCT)
#
#
#  (SPACE)
#     cover (VERB)
#
#
#
#
#
#  (SPACE)
#     The (DET)
#     War (PROPN)
#     of (ADP)
#     the (DET)
#     Worlds (PROPN)
#
#
#  (SPACE)
#     by (ADP)
#     H. (PROPN)
#     G. (PROPN)
#     Wells (PROPN)
#
#
#
#
#
#     (SPACE)
#     ‘ (PUNCT)
#     But (CCONJ)
#     who (PRON)
#     shall (AUX)
#     dwell (VERB)
#     in (ADP)
#     these (DET)
#     worlds (NOUN)
#     if (SCONJ)
#     they (PRON)
#     be (AUX)
#     inhabited (VERB)
#     ? (PUNCT)
#
#      (SPACE)
#     . (PUNCT)
#     . (PUNCT)
#     . (PUNCT)
#     Are (AUX)
#     we (PRON)
#     or (CCONJ)
#     they (PRON)
#     Lords (PROPN)
#     of (ADP)
#     the (DET)
#     World (PROPN)
#     ? (PUNCT)
#     . (PUNCT)
#     . (PUNCT)
#     . (PUNCT)
#     And (CCONJ)
#
#      (SPACE)
#     how (SCONJ)
#     are (AUX)
#     all (PRON)
#     things (NOUN)
#     made (VERB)
#     for (ADP)
#     man (NOUN)
#     ? (PUNCT)
#     ’ (PUNCT)
#
#                      (SPACE)
#     KEPLER (PROPN)
#     ( (PUNCT)
#     quoted (VERB)
#     in (ADP)
#     _ (PUNCT)
#     The (DET)
#     Anatomy (PROPN)
#     of (ADP)
#     Melancholy (PROPN)
#     _ (PROPN)
#     ) (PUNCT)
#
#
#
#
#
#  (SPACE)
#     Contents (PROPN)
#
#
#
#   (SPACE)
#     BOOK (PROPN)
#     ONE.—THE (X)
#     COMING (VERB)
#     OF (ADP)
#     THE (DET)
#     MARTIANS (NOUN)
#
#
#   (SPACE)
#     I. (NOUN)
#     THE (DET)
#     EVE (PROPN)
#     OF (ADP)
#     THE (DET)
#     WAR (PROPN)
#     . (PUNCT)
#
#   (SPACE)
#     II (PROPN)
#     . (PUNCT)
#     THE (DET)
#     FALLING (PROPN)
#     STAR (PROPN)
#     . (PUNCT)
#
#   (SPACE)
#     III (PROPN)
#     . (PUNCT)
#     ON (PROPN)
#     HORSELL (PROPN)
#     COMMON (PROPN)
#     . (PUNCT)
#
#   (SPACE)
#     IV (PROPN)
#     . (PUNCT)
#     THE (DET)
#     CYLINDER (PROPN)
#     OPENS (ADJ)
#     . (PUNCT)
#
#   (SPACE)
#     V. (PROPN)
#     THE (DET)
#     HEAT (PROPN)
#     - (PUNCT)
#     RAY (PROPN)
#     . (PUNCT)
#
#   (SPACE)
#     VI (PROPN)
#     . (PUNCT)
#     THE (DET)
#     HEAT (PROPN)
#     - (PUNCT)
#     RAY (PROPN)
#     IN (ADP)
#     THE (DET)
#     CHOBHAM (PROPN)
#     ROAD (PROPN)
#     . (PUNCT)
#
#   (SPACE)
#     VII (PROPN)
#     . (PUNCT)
#     HOW (SCONJ)
#     I (PRON)
#     REACHED (VERB)
#     HOME (PROPN)
#     . (PUNCT)
#
#   (SPACE)
#     VIII (PROPN)
#     . (PUNCT)
#     FRIDAY (PROPN)
#     NIGHT (PROPN)
#     . (PUNCT)
#
#   (SPACE)
#     IX (PROPN)
#     . (PUNCT)
#     THE (DET)
#     FIGHTING (PROPN)
#     BEGINS (PROPN)
#     . (PUNCT)
#
#   (SPACE)
#     X. (PROPN)
#     IN (ADP)
#     THE (DET)
#     STORM (PROPN)
#     . (PUNCT)
#
#   (SPACE)
#     XI (PROPN)
#     . (PUNCT)
#     AT (ADP)
#     THE (DET)
#     WINDOW (PROPN)
#     . (PUNCT)
#
#   (SPACE)
#     XII (PROPN)
#     . (PUNCT)
#     WHAT (PRON)
#     I (PRON)
#     SAW (VERB)
#     OF (ADP)
#     THE (DET)
#     DESTRUCTION (NOUN)
#     OF (ADP)
#     WEYBRIDGE (NOUN)
#     AND (CCONJ)
#     SHEPPERTON (PROPN)
#     . (PUNCT)
#
#   (SPACE)
#     XIII (PROPN)
#     . (PUNCT)
#     HOW (SCONJ)
#     I (PRON)
#     FELL (VERB)
#     IN (ADV)
#     WITH (ADP)
#     THE (DET)
#     CURATE (NOUN)
#     . (PUNCT)
#
#   (SPACE)
#     XIV (PROPN)
#     . (PUNCT)
#     IN (ADP)
#     LONDON (PROPN)
#     . (PUNCT)
#
#   (SPACE)
#     XV (PROPN)
#     . (PUNCT)
#     WHAT (PRON)
#     HAD (VERB)
#     HAPPENED (PROPN)
#     IN (ADP)
#     SURREY (PROPN)
#     . (PUNCT)
#
#   (SPACE)
#     XVI (PROPN)
#     . (PUNCT)
#     THE (DET)
#     EXODUS (PROPN)
#     FROM (ADP)
#     LONDON (PROPN)
#     . (PUNCT)
#
#   (SPACE)
#     XVII (PROPN)
#     . (PUNCT)
#     THE (DET)
#     “ (PUNCT)
#     THUNDER (NOUN)
#     CHILD (NOUN)
#     ” (PUNCT)
#     . (PUNCT)
#
#
#   (SPACE)
#     BOOK (PROPN)
#     TWO.—THE (PUNCT)
#     EARTH (PROPN)
#     UNDER (ADP)
#     THE (DET)
#     MARTIANS (NOUN)
#
#
#   (SPACE)
#     I. (PROPN)
#     UNDER (ADP)
#     FOOT (NOUN)
#     . (PUNCT)
#
#   (SPACE)
#     II (PROPN)
#     . (PUNCT)
#     WHAT (PRON)
#     WE (PRON)
#     SAW (VERB)
#     FROM (ADP)
#     THE (DET)
#     RUINED (PROPN)
#     HOUSE (PROPN)
#     . (PUNCT)
#
#   (SPACE)
#     III (PROPN)
#     . (PUNCT)
#     THE (DET)
#     DAYS (PROPN)
#     OF (ADP)
#     IMPRISONMENT (PROPN)
#     . (PUNCT)
#
#   (SPACE)
#     IV (PROPN)
#     . (PUNCT)
#     THE (DET)
#     DEATH (NOUN)
#     OF (ADP)
#     THE (DET)
#     CURATE (NOUN)
#     . (PUNCT)
#
#   (SPACE)
#     V. (PROPN)
#     THE (DET)
#     STILLNESS (PROPN)
#     . (PUNCT)
#
#   (SPACE)
#     VI (PROPN)
#     . (PUNCT)
#     THE (DET)
#     WORK (NOUN)
#     OF (ADP)
#     FIFTEEN (ADJ)
#     DAYS (NOUN)
#     . (PUNCT)
#
#   (SPACE)
#     VII (PROPN)
#     . (PUNCT)
#     THE (DET)
#     MAN (PROPN)
#     ON (PROPN)
#     PUTNEY (PROPN)
#     HILL (PROPN)
#     . (PUNCT)
#
#   (SPACE)
#     VIII (PROPN)
#     . (PUNCT)
#     DEAD (ADJ)
#     LONDON (PROPN)
#     . (PUNCT)
#
#   (SPACE)
#     IX (PROPN)
#     . (PUNCT)
#     WRECKAGE (PROPN)
#     . (PUNCT)
#
#   (SPACE)
#     X. (PROPN)
#     THE (DET)
#     EPILOGUE (PROPN)
#     . (PUNCT)
#
#
#
#
#
#  (SPACE)
#     BOOK (PROPN)
#     ONE (NUM)
#
#  (SPACE)
#     THE (DET)
#     COMING (NOUN)
#     OF (ADP)
#     THE (DET)
#     MARTIANS (PROPN)
#
#
#
#
#
#  (SPACE)
#     I. (PROPN)
#
#  (SPACE)
#     THE (DET)
#     EVE (PROPN)
#     OF (ADP)
#     THE (DET)
#     WAR (PROPN)
#     . (PUNCT)
#
#
#
#  (SPACE)
#     No (DET)
#     one (NOUN)
#     would (AUX)
#     have (AUX)
#     believed (VERB)
#     in (ADP)
#     the (DET)
#     last (ADJ)
#     years (NOUN)
#     of (ADP)
#     the (DET)
#     nineteenth (ADJ)
#     century (NOUN)
#
#  (SPACE)
#     that (SCONJ)
#     this (DET)
#     world (NOUN)
#     was (AUX)
#     being (AUX)
#     watched (VERB)
#     keenly (ADV)
#     and (CCONJ)
#     closely (ADV)
#     by (ADP)
#     intelligences (NOUN)
#
#  (SPACE)
#     greater (ADJ)
#     than (ADP)
#     man (NOUN)
#     ’s (PART)
#     and (CCONJ)
#     yet (ADV)
#     as (ADV)
#     mortal (ADJ)
#     as (ADP)
#     his (PRON)
#     own (ADJ)
#     ; (PUNCT)
#     that (SCONJ)
#     as (SCONJ)
#     men (NOUN)
#     busied (VERB)
#
#  (SPACE)
#     themselves (PRON)
#     about (ADP)
#     their (PRON)
#     various (ADJ)
#     concerns (NOUN)
#     they (PRON)
#     were (AUX)
#     scrutinised (VERB)
#     and (CCONJ)
#
#  (SPACE)
#     studied (VERB)
#     , (PUNCT)
#     perhaps (ADV)
#     almost (ADV)
#     as (ADV)
#     narrowly (ADV)
#     as (ADP)
#     a (DET)
#     man (NOUN)
#     with (ADP)
#     a (DET)
#     microscope (NOUN)
#     might (AUX)
#
#  (SPACE)
#     scrutinise (VERB)
#     the (DET)
#     transient (ADJ)
#     creatures (NOUN)
#     that (PRON)
#     swarm (NOUN)
#     and (CCONJ)
#     multiply (NOUN)
#     in (ADP)
#     a (DET)
#     drop (NOUN)
#     of (ADP)
#
#  (SPACE)
#     water (NOUN)
#     . (PUNCT)
#     With (SCONJ)
#     infinite (ADJ)
#     complacency (NOUN)
#     men (NOUN)
#     went (VERB)
#     to (ADP)
#     and (CCONJ)
#     fro (VERB)
#     over (ADP)
#     this (DET)
#     globe (NOUN)
#
#  (SPACE)
#     about (ADP)
#     their (PRON)
#     little (ADJ)
#     affairs (NOUN)
#     , (PUNCT)
#     serene (ADJ)
#     in (ADP)
#     their (PRON)
#     assurance (NOUN)
#     of (ADP)
#     their (PRON)
#     empire (NOUN)
#
#  (SPACE)
#     over (ADV)
#     matter (NOUN)
#     . (PUNCT)
#     It (PRON)
#     is (AUX)
#     possible (ADJ)
#     that (SCONJ)
#     the (DET)
#     infusoria (NOUN)
#     under (ADP)
#     the (DET)
#     microscope (NOUN)
#     do (VERB)
#
#  (SPACE)
#     the (DET)
#     same (ADJ)
#     . (PUNCT)
#     No (DET)
#     one (NOUN)
#     gave (VERB)
#     a (DET)
#     thought (NOUN)
#     to (ADP)
#     the (DET)
#     older (ADJ)
#     worlds (NOUN)
#     of (ADP)
#     space (NOUN)
#     as (ADP)
#     sources (NOUN)
#
#  (SPACE)
#     of (ADP)
#     human (ADJ)
#     danger (NOUN)
#     , (PUNCT)
#     or (CCONJ)
#     thought (VERB)
#     of (ADP)
#     them (PRON)
#     only (ADV)
#     to (PART)
#     dismiss (VERB)
#     the (DET)
#     idea (NOUN)
#     of (ADP)
#     life (NOUN)
#
#  (SPACE)
#     upon (SCONJ)
#     them (PRON)
#     as (ADP)
#     impossible (ADJ)
#     or (CCONJ)
#     improbable (ADJ)
#     . (PUNCT)
#     It (PRON)
#     is (AUX)
#     curious (ADJ)
#     to (PART)
#     recall (VERB)
#     some (PRON)
#     of (ADP)
#
#  (SPACE)
#     the (DET)
#     mental (ADJ)
#     habits (NOUN)
#     of (ADP)
#     those (DET)
#     departed (VERB)
#     days (NOUN)
#     . (PUNCT)
#     At (ADP)
#     most (ADJ)
#     terrestrial (ADJ)
#     men (NOUN)
#
#  (SPACE)
#     fancied (VERB)
#     there (PRON)
#     might (AUX)
#     be (AUX)
#     other (ADJ)
#     men (NOUN)
#     upon (SCONJ)
#     Mars (PROPN)
#     , (PUNCT)
#     perhaps (ADV)
#     inferior (ADJ)
#     to (ADP)
#
#  (SPACE)
#     themselves (PRON)
#     and (CCONJ)
#     ready (ADJ)
#     to (PART)
#     welcome (VERB)
#     a (DET)
#     missionary (ADJ)
#     enterprise (NOUN)
#     . (PUNCT)
#     Yet (CCONJ)
#     across (ADP)
#     the (DET)
#
#  (SPACE)
#     gulf (NOUN)
#     of (ADP)
#     space (NOUN)
#     , (PUNCT)
#     minds (NOUN)
#     that (PRON)
#     are (AUX)
#     to (ADP)
#     our (PRON)
#     minds (NOUN)
#     as (ADP)
#     ours (NOUN)
#     are (AUX)
#     to (ADP)
#     those (PRON)
#     of (ADP)
#     the (DET)
#
#  (SPACE)
#     beasts (NOUN)
#     that (PRON)
#     perish (VERB)
#     , (PUNCT)
#     intellects (VERB)
#     vast (ADJ)
#     and (CCONJ)
#     cool (ADJ)
#     and (CCONJ)
#     unsympathetic (ADJ)
#     , (PUNCT)
#
#  (SPACE)
#     regarded (VERB)
#     this (DET)
#     earth (NOUN)
#     with (ADP)
#     envious (ADJ)
#     eyes (NOUN)
#     , (PUNCT)
#     and (CCONJ)
#     slowly (ADV)
#     and (CCONJ)
#     surely (ADV)
#     drew (VERB)
#     their (PRON)
#
#  (SPACE)
#     plans (NOUN)
#     against (ADP)
#     us (PRON)
#     . (PUNCT)
#     And (CCONJ)
#     early (ADV)
#     in (ADP)
#     the (DET)
#     twentieth (ADJ)
#     century (NOUN)
#     came (VERB)
#     the (DET)
#     great (ADJ)
#
#  (SPACE)
#     disillusionment (NOUN)
#     . (PUNCT)
#
#
#  (SPACE)
#     The (DET)
#     planet (NOUN)
#     Mars (PROPN)
#     , (PUNCT)
#     I (PRON)
#     scarcely (ADV)
#     need (VERB)
#     remind (VERB)
#     the (DET)
#     reader (NOUN)
#     , (PUNCT)
#     revolves (VERB)
#     about (ADP)
#     the (DET)
#
#  (SPACE)
#     sun (NOUN)
#     at (ADP)
#     a (DET)
#     mean (ADJ)
#     distance (NOUN)
#     of (ADP)
#     140,000,000 (NUM)
#     miles (NOUN)
#     , (PUNCT)
#     and (CCONJ)
#     the (DET)
#     light (NOUN)
#     and (CCONJ)
#     heat (VERB)
#     it (PRON)
#
#  (SPACE)
#     receives (VERB)
#     from (ADP)
#     the (DET)
#     sun (NOUN)
#     is (AUX)
#     barely (ADV)
#     half (NOUN)
#     of (ADP)
#     that (PRON)
#     received (VERB)
#     by (ADP)
#     this (DET)
#     world (NOUN)
#     . (PUNCT)
#     It (PRON)
#
#  (SPACE)
#     must (AUX)
#     be (AUX)
#     , (PUNCT)
#     if (SCONJ)
#     the (DET)
#     nebular (ADJ)
#     hypothesis (NOUN)
#     has (VERB)
#     any (DET)
#     truth (NOUN)
#     , (PUNCT)
#     older (ADJ)
#     than (ADP)
#     our (PRON)
#     world (NOUN)
#     ; (PUNCT)
#
#  (SPACE)
#     and (CCONJ)
#     long (ADV)
#     before (SCONJ)
#     this (DET)
#     earth (NOUN)
#     ceased (VERB)
#     to (PART)
#     be (AUX)
#     molten (ADJ)
#     , (PUNCT)
#     life (NOUN)
#     upon (SCONJ)
#     its (PRON)
#     surface (NOUN)
#
#  (SPACE)
#     must (AUX)
#     have (AUX)
#     begun (VERB)
#     its (PRON)
#     course (NOUN)
#     . (PUNCT)
#     The (DET)
#     fact (NOUN)
#     that (SCONJ)
#     it (PRON)
#     is (AUX)
#     scarcely (ADV)
#     one (NUM)
#     seventh (ADJ)
#     of (ADP)
#
#  (SPACE)
#     the (DET)
#     volume (NOUN)
#     of (ADP)
#     the (DET)
#     earth (NOUN)
#     must (AUX)
#     have (AUX)
#     accelerated (VERB)
#     its (PRON)
#     cooling (NOUN)
#     to (ADP)
#     the (DET)
#
#  (SPACE)
#     temperature (NOUN)
#     at (ADP)
#     which (PRON)
#     life (NOUN)
#     could (AUX)
#     begin (VERB)
#     . (PUNCT)
#     It (PRON)
#     has (VERB)
#     air (NOUN)
#     and (CCONJ)
#     water (NOUN)
#     and (CCONJ)
#     all (PRON)
#
#  (SPACE)
#     that (PRON)
#     is (AUX)
#     necessary (ADJ)
#     for (ADP)
#     the (DET)
#     support (NOUN)
#     of (ADP)
#     animated (VERB)
#     existence (NOUN)
#     . (PUNCT)
#
#
#  (SPACE)
#     Yet (CCONJ)
#     so (ADV)
#     vain (ADJ)
#     is (AUX)
#     man (NOUN)
#     , (PUNCT)
#     and (CCONJ)
#     so (ADV)
#     blinded (VERB)
#     by (ADP)
#     his (PRON)
#     vanity (NOUN)
#     , (PUNCT)
#     that (SCONJ)
#     no (DET)
#     writer (NOUN)
#     , (PUNCT)
#     up (ADP)
#     to (ADP)
#
#  (SPACE)
#     the (DET)
#     very (ADJ)
#     end (NOUN)
#     of (ADP)
#     the (DET)
#     nineteenth (ADJ)
#     century (NOUN)
#     , (PUNCT)
#     expressed (VERB)
#     any (DET)
#     idea (NOUN)
#     that (SCONJ)
#
#  (SPACE)
#     intelligent (ADJ)
#     life (NOUN)
#     might (AUX)
#     have (AUX)
#     developed (VERB)
#     there (ADV)
#     far (ADV)
#     , (PUNCT)
#     or (CCONJ)
#     indeed (ADV)
#     at (ADV)
#     all (ADV)
#     , (PUNCT)
#
#  (SPACE)
#     beyond (ADP)
#     its (PRON)
#     earthly (ADJ)
#     level (NOUN)
#     . (PUNCT)
#     Nor (CCONJ)
#     was (AUX)
#     it (PRON)
#     generally (ADV)
#     understood (VERB)
#     that (SCONJ)
#     since (SCONJ)
#
#  (SPACE)
#     Mars (PROPN)
#     is (AUX)
#     older (ADJ)
#     than (ADP)
#     our (PRON)
#     earth (NOUN)
#     , (PUNCT)
#     with (ADP)
#     scarcely (ADV)
#     a (DET)
#     quarter (NOUN)
#     of (ADP)
#     the (DET)
#
#  (SPACE)
#     superficial (ADJ)
#     area (NOUN)
#     and (CCONJ)
#     remoter (NOUN)
#     from (ADP)
#     the (DET)
#     sun (NOUN)
#     , (PUNCT)
#     it (PRON)
#     necessarily (ADV)
#     follows (VERB)
#     that (SCONJ)
#
#  (SPACE)
#     it (PRON)
#     is (AUX)
#     not (PART)
#     only (ADV)
#     more (ADV)
#     distant (ADJ)
#     from (ADP)
#     time (NOUN)
#     ’s (PART)
#     beginning (NOUN)
#     but (CCONJ)
#     nearer (VERB)
#     its (PRON)
#     end (NOUN)
#     . (PUNCT)
#
#
#  (SPACE)
#     The (DET)
#     secular (ADJ)
#     cooling (NOUN)
#     that (PRON)
#     must (AUX)
#     someday (ADV)
#     overtake (VERB)
#     our (PRON)
#     planet (NOUN)
#     has (AUX)
#     already (ADV)
#
#  (SPACE)
#     gone (VERB)
#     far (ADV)
#     indeed (ADV)
#     with (ADP)
#     our (PRON)
#     neighbour (NOUN)
#     . (PUNCT)
#     Its (PRON)
#     physical (ADJ)
#     condition (NOUN)
#     is (AUX)
#     still (ADV)
#
#  (SPACE)
#     largely (ADV)
#     a (DET)
#     mystery (NOUN)
#     , (PUNCT)
#     but (CCONJ)
#     we (PRON)
#     know (VERB)
#     now (ADV)
#     that (SCONJ)
#     even (ADV)
#     in (ADP)
#     its (PRON)
#     equatorial (ADJ)
#     region (NOUN)
#
#  (SPACE)
#     the (DET)
#     midday (NOUN)
#     temperature (NOUN)
#     barely (ADV)
#     approaches (VERB)
#     that (PRON)
#     of (ADP)
#     our (PRON)
#     coldest (ADJ)
#     winter (NOUN)
#     . (PUNCT)
#
#  (SPACE)
#     Its (PRON)
#     air (NOUN)
#     is (AUX)
#     much (ADV)
#     more (ADV)
#     attenuated (VERB)
#     than (ADP)
#     ours (NOUN)
#     , (PUNCT)
#     its (PRON)
#     oceans (NOUN)
#     have (AUX)
#     shrunk (VERB)
#     until (SCONJ)
#
#  (SPACE)
#     they (PRON)
#     cover (VERB)
#     but (CCONJ)
#     a (DET)
#     third (NOUN)
#     of (ADP)
#     its (PRON)
#     surface (NOUN)
#     , (PUNCT)
#     and (CCONJ)
#     as (SCONJ)
#     its (PRON)
#     slow (ADJ)
#     seasons (NOUN)
#     change (VERB)
#
#  (SPACE)
#     huge (ADJ)
#     snowcaps (NOUN)
#     gather (VERB)
#     and (CCONJ)
#     melt (VERB)
#     about (ADP)
#     either (CCONJ)
#     pole (NOUN)
#     and (CCONJ)
#     periodically (ADV)
#
#  (SPACE)
#     inundate (VERB)
#     its (PRON)
#     temperate (NOUN)
#     zones (NOUN)
#     . (PUNCT)
#     That (DET)
#     last (ADJ)
#     stage (NOUN)
#     of (ADP)
#     exhaustion (NOUN)
#     , (PUNCT)
#     which (PRON)
#     to (PART)
#
#  (SPACE)
#     us (PRON)
#     is (AUX)
#     still (ADV)
#     incredibly (ADV)
#     remote (ADJ)
#     , (PUNCT)
#     has (AUX)
#     become (VERB)
#     a (DET)
#     present (ADJ)
#     - (PUNCT)
#     day (NOUN)
#     problem (NOUN)
#     for (ADP)
#     the (DET)
#
#  (SPACE)
#     inhabitants (NOUN)
#     of (ADP)
#     Mars (PROPN)
#     . (PUNCT)
#     The (DET)
#     immediate (ADJ)
#     pressure (NOUN)
#     of (ADP)
#     necessity (NOUN)
#     has (AUX)
#     brightened (VERB)
#
#  (SPACE)
#     their (PRON)
#     intellects (NOUN)
#     , (PUNCT)
#     enlarged (VERB)
#     their (PRON)
#     powers (NOUN)
#     , (PUNCT)
#     and (CCONJ)
#     hardened (VERB)
#     their (PRON)
#     hearts (NOUN)
#     . (PUNCT)
#     And (CCONJ)
#
#  (SPACE)
#     looking (VERB)
#     across (ADP)
#     space (NOUN)
#     with (ADP)
#     instruments (NOUN)
#     , (PUNCT)
#     and (CCONJ)
#     intelligences (NOUN)
#     such (ADJ)
#     as (SCONJ)
#     we (PRON)
#
#  (SPACE)
#     have (AUX)
#     scarcely (ADV)
#     dreamed (VERB)
#     of (ADP)
#     , (PUNCT)
#     they (PRON)
#     see (VERB)
#     , (PUNCT)
#     at (ADP)
#     its (PRON)
#     nearest (ADJ)
#     distance (NOUN)
#     only (ADV)
#
#  (SPACE)
#     35,000,000 (NUM)
#     of (ADP)
#     miles (NOUN)
#     sunward (NOUN)
#     of (ADP)
#     them (PRON)
#     , (PUNCT)
#     a (DET)
#     morning (NOUN)
#     star (NOUN)
#     of (ADP)
#     hope (NOUN)
#     , (PUNCT)
#     our (PRON)
#     own (ADJ)
#
#  (SPACE)
#     warmer (ADJ)
#     planet (NOUN)
#     , (PUNCT)
#     green (ADJ)
#     with (ADP)
#     vegetation (NOUN)
#     and (CCONJ)
#     grey (NOUN)
#     with (ADP)
#     water (NOUN)
#     , (PUNCT)
#     with (ADP)
#     a (DET)
#     cloudy (ADJ)
#
#  (SPACE)
#     atmosphere (NOUN)
#     eloquent (ADJ)
#     of (ADP)
#     fertility (NOUN)
#     , (PUNCT)
#     with (ADP)
#     glimpses (NOUN)
#     through (ADP)
#     its (PRON)
#     drifting (VERB)
#
#  (SPACE)
#     cloud (ADJ)
#     wisps (NOUN)
#     of (ADP)
#     broad (ADJ)
#     stretches (NOUN)
#     of (ADP)
#     populous (ADJ)
#     country (NOUN)
#     and (CCONJ)
#     narrow (ADJ)
#     , (PUNCT)
#
#  (SPACE)
#     navy (NOUN)
#     - (PUNCT)
#     crowded (VERB)
#     seas (NOUN)
#     . (PUNCT)
#
#
#  (SPACE)
#     And (CCONJ)
#     we (PRON)
#     men (NOUN)
#     , (PUNCT)
#     the (DET)
#     creatures (NOUN)
#     who (PRON)
#     inhabit (VERB)
#     this (DET)
#     earth (NOUN)
#     , (PUNCT)
#     must (AUX)
#     be (AUX)
#     to (ADP)
#     them (PRON)
#     at (ADP)
#
#  (SPACE)
#     least (ADJ)
#     as (ADP)
#     alien (ADJ)
#     and (CCONJ)
#     lowly (ADJ)
#     as (SCONJ)
#     are (AUX)
#     the (DET)
#     monkeys (NOUN)
#     and (CCONJ)
#     lemurs (NOUN)
#     to (ADP)
#     us (PRON)
#     . (PUNCT)
#     The (DET)
#
#  (SPACE)
#     intellectual (ADJ)
#     side (NOUN)
#     of (ADP)
#     man (NOUN)
#     already (ADV)
#     admits (VERB)
#     that (SCONJ)
#     life (NOUN)
#     is (AUX)
#     an (DET)
#     incessant (ADJ)
#
#  (SPACE)
#     struggle (NOUN)
#     for (ADP)
#     existence (NOUN)
#     , (PUNCT)
#     and (CCONJ)
#     it (PRON)
#     would (AUX)
#     seem (VERB)
#     that (SCONJ)
#     this (PRON)
#     too (ADV)
#     is (AUX)
#     the (DET)
#     belief (NOUN)
#
#  (SPACE)
#     of (ADP)
#     the (DET)
#     minds (NOUN)
#     upon (SCONJ)
#     Mars (PROPN)
#     . (PUNCT)
#     Their (PRON)
#     world (NOUN)
#     is (AUX)
#     far (ADV)
#     gone (VERB)
#     in (ADP)
#     its (PRON)
#     cooling (NOUN)
#     and (CCONJ)
#     this (DET)
#
#  (SPACE)
#     world (NOUN)
#     is (AUX)
#     still (ADV)
#     crowded (VERB)
#     with (ADP)
#     life (NOUN)
#     , (PUNCT)
#     but (CCONJ)
#     crowded (VERB)
#     only (ADV)
#     with (ADP)
#     what (PRON)
#     they (PRON)
#
#  (SPACE)
#     regard (VERB)
#     as (ADP)
#     inferior (ADJ)
#     animals (NOUN)
#     . (PUNCT)
#     To (PART)
#     carry (VERB)
#     warfare (NOUN)
#     sunward (NOUN)
#     is (AUX)
#     , (PUNCT)
#     indeed (ADV)
#     , (PUNCT)
#     their (PRON)
#
#  (SPACE)
#     only (ADV)
#     escape (VERB)
#     from (ADP)
#     the (DET)
#     destruction (NOUN)
#     that (PRON)
#     , (PUNCT)
#     generation (NOUN)
#     after (ADP)
#     generation (NOUN)
#     , (PUNCT)
#
#  (SPACE)
#     creeps (VERB)
#     upon (SCONJ)
#     them (PRON)
#     . (PUNCT)
#
#
#  (SPACE)
#     And (CCONJ)
#     before (SCONJ)
#     we (PRON)
#     judge (VERB)
#     of (ADP)
#     them (PRON)
#     too (ADV)
#     harshly (ADV)
#     we (PRON)
#     must (AUX)
#     remember (VERB)
#     what (PRON)
#     ruthless (ADJ)
#
#  (SPACE)
#     and (CCONJ)
#     utter (ADJ)
#     destruction (NOUN)
#     our (PRON)
#     own (ADJ)
#     species (NOUN)
#     has (AUX)
#     wrought (VERB)
#     , (PUNCT)
#     not (PART)
#     only (ADV)
#     upon (SCONJ)
#
#  (SPACE)
#     animals (NOUN)
#     , (PUNCT)
#     such (ADJ)
#     as (ADP)
#     the (DET)
#     vanished (VERB)
#     bison (NOUN)
#     and (CCONJ)
#     the (DET)
#     dodo (NOUN)
#     , (PUNCT)
#     but (CCONJ)
#     upon (SCONJ)
#     its (PRON)
#     inferior (ADJ)
#
#  (SPACE)
#     races (NOUN)
#     . (PUNCT)
#     The (DET)
#     Tasmanians (PROPN)
#     , (PUNCT)
#     in (ADP)
#     spite (NOUN)
#     of (ADP)
#     their (PRON)
#     human (NOUN)
#     likeness (NOUN)
#     , (PUNCT)
#     were (AUX)
#     entirely (ADV)
#
#  (SPACE)
#     swept (VERB)
#     out (ADP)
#     of (ADP)
#     existence (NOUN)
#     in (ADP)
#     a (DET)
#     war (NOUN)
#     of (ADP)
#     extermination (NOUN)
#     waged (VERB)
#     by (ADP)
#     European (ADJ)
#
#  (SPACE)
#     immigrants (NOUN)
#     , (PUNCT)
#     in (ADP)
#     the (DET)
#     space (NOUN)
#     of (ADP)
#     fifty (NUM)
#     years (NOUN)
#     . (PUNCT)
#     Are (AUX)
#     we (PRON)
#     such (ADJ)
#     apostles (NOUN)
#     of (ADP)
#     mercy (NOUN)
#
#  (SPACE)
#     as (SCONJ)
#     to (PART)
#     complain (VERB)
#     if (SCONJ)
#     the (DET)
#     Martians (PROPN)
#     warred (VERB)
#     in (ADP)
#     the (DET)
#     same (ADJ)
#     spirit (NOUN)
#     ? (PUNCT)
#
#
#  (SPACE)
#     The (DET)
#     Martians (PROPN)
#     seem (VERB)
#     to (PART)
#     have (AUX)
#     calculated (VERB)
#     their (PRON)
#     descent (NOUN)
#     with (ADP)
#     amazing (ADJ)
#
#  (SPACE)
#     subtlety (NOUN)
#     — (PUNCT)
#     their (PRON)
#     mathematical (ADJ)
#     learning (NOUN)
#     is (AUX)
#     evidently (ADV)
#     far (ADV)
#     in (ADP)
#     excess (NOUN)
#     of (ADP)
#
#  (SPACE)
#     ours (NOUN)
#     — (PUNCT)
#     and (CCONJ)
#     to (PART)
#     have (AUX)
#     carried (VERB)
#     out (ADP)
#     their (PRON)
#     preparations (NOUN)
#     with (ADP)
#     a (DET)
#     well (ADV)
#     - (PUNCT)
#     nigh (NOUN)
#
#  (SPACE)
#     perfect (ADJ)
#     unanimity (NOUN)
#     . (PUNCT)
#     Had (AUX)
#     our (PRON)
#     instruments (NOUN)
#     permitted (VERB)
#     it (PRON)
#     , (PUNCT)
#     we (PRON)
#     might (AUX)
#     have (AUX)
#     seen (VERB)
#
#  (SPACE)
#     the (DET)
#     gathering (VERB)
#     trouble (NOUN)
#     far (ADV)
#     back (ADV)
#     in (ADP)
#     the (DET)
#     nineteenth (ADJ)
#     century (NOUN)
#     . (PUNCT)
#     Men (NOUN)
#     like (ADP)
#
#  (SPACE)
#     Schiaparelli (PROPN)
#     watched (VERB)
#     the (DET)
#     red (ADJ)
#     planet (NOUN)
#     — (PUNCT)
#     it (PRON)
#     is (AUX)
#     odd (ADJ)
#     , (PUNCT)
#     by (ADP)
#     - (PUNCT)
#     the (DET)
#     - (PUNCT)
#     bye (NOUN)
#     , (PUNCT)
#     that (SCONJ)
#     for (ADP)
#
#  (SPACE)
#     countless (ADJ)
#     centuries (NOUN)
#     Mars (PROPN)
#     has (AUX)
#     been (AUX)
#     the (DET)
#     star (NOUN)
#     of (ADP)
#     war (NOUN)
#     — (PUNCT)
#     but (CCONJ)
#     failed (VERB)
#     to (PART)
#
#  (SPACE)
#     interpret (VERB)
#     the (DET)
#     fluctuating (NOUN)
#     appearances (NOUN)
#     of (ADP)
#     the (DET)
#     markings (NOUN)
#     they (PRON)
#     mapped (VERB)
#     so (ADV)
#
#  (SPACE)
#     well (ADV)
#     . (PUNCT)
#     All (DET)
#     that (DET)
#     time (NOUN)
#     the (DET)
#     Martians (PROPN)
#     must (AUX)
#     have (AUX)
#     been (AUX)
#     getting (VERB)
#     ready (ADJ)
#     . (PUNCT)
#
#
#  (SPACE)
#     During (ADP)
#     the (DET)
#     opposition (NOUN)
#     of (ADP)
#     1894 (NUM)
#     a (DET)
#     great (ADJ)
#     light (NOUN)
#     was (AUX)
#     seen (VERB)
#     on (ADP)
#     the (DET)
#     illuminated (ADJ)
#
#  (SPACE)
#     part (NOUN)
#     of (ADP)
#     the (DET)
#     disk (NOUN)
#     , (PUNCT)
#     first (ADV)
#     at (ADP)
#     the (DET)
#     Lick (PROPN)
#     Observatory (PROPN)
#     , (PUNCT)
#     then (ADV)
#     by (ADP)
#     Perrotin (PROPN)
#     of (ADP)
#
#  (SPACE)
#     Nice (PROPN)
#     , (PUNCT)
#     and (CCONJ)
#     then (ADV)
#     by (ADP)
#     other (ADJ)
#     observers (NOUN)
#     . (PUNCT)
#     English (ADJ)
#     readers (NOUN)
#     heard (VERB)
#     of (ADP)
#     it (PRON)
#     first (ADV)
#     in (ADP)
#
#  (SPACE)
#     the (DET)
#     issue (NOUN)
#     of (ADP)
#     _ (PROPN)
#     Nature (NOUN)
#     _ (NUM)
#     dated (VERB)
#     August (PROPN)
#     2 (NUM)
#     . (PUNCT)
#     I (PRON)
#     am (AUX)
#     inclined (ADJ)
#     to (PART)
#     think (VERB)
#     that (SCONJ)
#     this (DET)
#
#  (SPACE)
#     blaze (NOUN)
#     may (AUX)
#     have (AUX)
#     been (AUX)
#     the (DET)
#     casting (NOUN)
#     of (ADP)
#     the (DET)
#     huge (ADJ)
#     gun (NOUN)
#     , (PUNCT)
#     in (ADP)
#     the (DET)
#     vast (ADJ)
#     pit (NOUN)
#     sunk (VERB)
#
#  (SPACE)
#     into (ADP)
#     their (PRON)
#     planet (NOUN)
#     , (PUNCT)
#     from (ADP)
#     which (PRON)
#     their (PRON)
#     shots (NOUN)
#     were (AUX)
#     fired (VERB)
#     at (ADP)
#     us (PRON)
#     . (PUNCT)
#     Peculiar (ADJ)
#
#  (SPACE)
#     markings (NOUN)
#     , (PUNCT)
#     as (ADP)
#     yet (ADV)
#     unexplained (ADJ)
#     , (PUNCT)
#     were (AUX)
#     seen (VERB)
#     near (ADP)
#     the (DET)
#     site (NOUN)
#     of (ADP)
#     that (DET)
#     outbreak (NOUN)
#
#  (SPACE)
#     during (ADP)
#     the (DET)
#     next (ADJ)
#     two (NUM)
#     oppositions (NOUN)
#     . (PUNCT)
#
#
#  (SPACE)
#     The (DET)
#     storm (NOUN)
#     burst (VERB)
#     upon (SCONJ)
#     us (PRON)
#     six (NUM)
#     years (NOUN)
#     ago (ADV)
#     now (ADV)
#     . (PUNCT)
#     As (SCONJ)
#     Mars (PROPN)
#     approached (VERB)
#
#  (SPACE)
#     opposition (NOUN)
#     , (PUNCT)
#     Lavelle (PROPN)
#     of (ADP)
#     Java (PROPN)
#     set (VERB)
#     the (DET)
#     wires (NOUN)
#     of (ADP)
#     the (DET)
#     astronomical (ADJ)
#     exchange (NOUN)
#
#  (SPACE)
#     palpitating (NOUN)
#     with (ADP)
#     the (DET)
#     amazing (ADJ)
#     intelligence (NOUN)
#     of (ADP)
#     a (DET)
#     huge (ADJ)
#     outbreak (NOUN)
#     of (ADP)
#
#  (SPACE)
#     incandescent (NOUN)
#     gas (NOUN)
#     upon (SCONJ)
#     the (DET)
#     planet (NOUN)
#     . (PUNCT)
#     It (PRON)
#     had (AUX)
#     occurred (VERB)
#     towards (ADP)
#     midnight (NOUN)
#     of (ADP)
#
#  (SPACE)
#     the (DET)
#     twelfth (ADJ)
#     ; (PUNCT)
#     and (CCONJ)
#     the (DET)
#     spectroscope (NOUN)
#     , (PUNCT)
#     to (PART)
#     which (PRON)
#     he (PRON)
#     had (AUX)
#     at (ADP)
#     once (ADV)
#     resorted (VERB)
#     , (PUNCT)
#
#  (SPACE)
#     indicated (VERB)
#     a (DET)
#     mass (NOUN)
#     of (ADP)
#     flaming (VERB)
#     gas (NOUN)
#     , (PUNCT)
#     chiefly (ADV)
#     hydrogen (NOUN)
#     , (PUNCT)
#     moving (VERB)
#     with (ADP)
#     an (DET)
#
#  (SPACE)
#     enormous (ADJ)
#     velocity (NOUN)
#     towards (ADP)
#     this (DET)
#     earth (NOUN)
#     . (PUNCT)
#     This (DET)
#     jet (NOUN)
#     of (ADP)
#     fire (NOUN)
#     had (AUX)
#     become (VERB)
#
#  (SPACE)
#     invisible (ADJ)
#     about (ADV)
#     a (PRON)
#     quarter (NOUN)
#     past (NOUN)
#     twelve (NUM)
#     . (PUNCT)
#     He (PRON)
#     compared (VERB)
#     it (PRON)
#     to (ADP)
#     a (DET)
#     colossal (ADJ)
#
#  (SPACE)
#     puff (NOUN)
#     of (ADP)
#     flame (NOUN)
#     suddenly (ADV)
#     and (CCONJ)
#     violently (ADV)
#     squirted (VERB)
#     out (ADP)
#     of (ADP)
#     the (DET)
#     planet (NOUN)
#     , (PUNCT)
#     “ (PUNCT)
#     as (SCONJ)
#
#  (SPACE)
#     flaming (VERB)
#     gases (NOUN)
#     rushed (VERB)
#     out (ADP)
#     of (ADP)
#     a (DET)
#     gun (NOUN)
#     . (PUNCT)
#     ” (PUNCT)
#
#
#  (SPACE)
#     A (DET)
#     singularly (ADV)
#     appropriate (ADJ)
#     phrase (NOUN)
#     it (PRON)
#     proved (VERB)
#     . (PUNCT)
#     Yet (CCONJ)
#     the (DET)
#     next (ADJ)
#     day (NOUN)
#     there (PRON)
#     was (VERB)
#
#  (SPACE)
#     nothing (PRON)
#     of (ADP)
#     this (PRON)
#     in (ADP)
#     the (DET)
#     papers (NOUN)
#     except (SCONJ)
#     a (DET)
#     little (ADJ)
#     note (NOUN)
#     in (ADP)
#     the (DET)
#     _ (NOUN)
#     Daily (PROPN)
#
#  (SPACE)
#     Telegraph (PROPN)
#     _ (PROPN)
#     , (PUNCT)
#     and (CCONJ)
#     the (DET)
#     world (NOUN)
#     went (VERB)
#     in (ADP)
#     ignorance (NOUN)
#     of (ADP)
#     one (NUM)
#     of (ADP)
#     the (DET)
#     gravest (ADJ)
#
#  (SPACE)
#     dangers (NOUN)
#     that (PRON)
#     ever (ADV)
#     threatened (VERB)
#     the (DET)
#     human (ADJ)
#     race (NOUN)
#     . (PUNCT)
#     I (PRON)
#     might (AUX)
#     not (PART)
#     have (AUX)
#     heard (VERB)
#     of (ADP)
#
#  (SPACE)
#     the (DET)
#     eruption (NOUN)
#     at (ADV)
#     all (ADV)
#     had (AUX)
#     I (PRON)
#     not (PART)
#     met (VERB)
#     Ogilvy (PROPN)
#     , (PUNCT)
#     the (DET)
#     well (ADV)
#     - (PUNCT)
#     known (VERB)
#     astronomer (NOUN)
#     , (PUNCT)
#     at (ADP)
#
#  (SPACE)
#     Ottershaw (PROPN)
#     . (PUNCT)
#     He (PRON)
#     was (AUX)
#     immensely (ADV)
#     excited (ADJ)
#     at (ADP)
#     the (DET)
#     news (NOUN)
#     , (PUNCT)
#     and (CCONJ)
#     in (ADP)
#     the (DET)
#     excess (NOUN)
#     of (ADP)
#
#  (SPACE)
#     his (PRON)
#     feelings (NOUN)
#     invited (VERB)
#     me (PRON)
#     up (ADP)
#     to (PART)
#     take (VERB)
#     a (DET)
#     turn (NOUN)
#     with (ADP)
#     him (PRON)
#     that (DET)
#     night (NOUN)
#     in (ADP)
#     a (DET)
#
#  (SPACE)
#     scrutiny (NOUN)
#     of (ADP)
#     the (DET)
#     red (ADJ)
#     planet (NOUN)
#     . (PUNCT)
#
#
#  (SPACE)
#     In (ADP)
#     spite (NOUN)
#     of (ADP)
#     all (PRON)
#     that (PRON)
#     has (AUX)
#     happened (VERB)
#     since (ADV)
#     , (PUNCT)
#     I (PRON)
#     still (ADV)
#     remember (VERB)
#     that (SCONJ)
#     vigil (NOUN)
#
#  (SPACE)
#     very (ADV)
#     distinctly (ADV)
#     : (PUNCT)
#     the (DET)
#     black (ADJ)
#     and (CCONJ)
#     silent (ADJ)
#     observatory (NOUN)
#     , (PUNCT)
#     the (DET)
#     shadowed (VERB)
#     lantern (NOUN)
#
#  (SPACE)
#     throwing (VERB)
#     a (DET)
#     feeble (ADJ)
#     glow (NOUN)
#     upon (SCONJ)
#     the (DET)
#     floor (NOUN)
#     in (ADP)
#     the (DET)
#     corner (NOUN)
#     , (PUNCT)
#     the (DET)
#     steady (ADJ)
#     ticking (NOUN)
#
#  (SPACE)
#     of (ADP)
#     the (DET)
#     clockwork (NOUN)
#     of (ADP)
#     the (DET)
#     telescope (NOUN)
#     , (PUNCT)
#     the (DET)
#     little (ADJ)
#     slit (NOUN)
#     in (ADP)
#     the (DET)
#     roof (NOUN)
#     — (PUNCT)
#     an (DET)
#
#  (SPACE)
#     oblong (ADJ)
#     profundity (NOUN)
#     with (ADP)
#     the (DET)
#     stardust (NOUN)
#     streaked (VERB)
#     across (ADP)
#     it (PRON)
#     . (PUNCT)
#     Ogilvy (PROPN)
#     moved (VERB)
#
#  (SPACE)
#     about (ADV)
#     , (PUNCT)
#     invisible (ADJ)
#     but (CCONJ)
#     audible (ADJ)
#     . (PUNCT)
#     Looking (VERB)
#     through (ADP)
#     the (DET)
#     telescope (NOUN)
#     , (PUNCT)
#     one (PRON)
#     saw (VERB)
#     a (DET)
#
#  (SPACE)
#     circle (NOUN)
#     of (ADP)
#     deep (ADJ)
#     blue (NOUN)
#     and (CCONJ)
#     the (DET)
#     little (ADJ)
#     round (ADJ)
#     planet (NOUN)
#     swimming (NOUN)
#     in (ADP)
#     the (DET)
#     field (NOUN)
#     . (PUNCT)
#
#  (SPACE)
#     It (PRON)
#     seemed (VERB)
#     such (DET)
#     a (DET)
#     little (ADJ)
#     thing (NOUN)
#     , (PUNCT)
#     so (ADV)
#     bright (ADJ)
#     and (CCONJ)
#     small (ADJ)
#     and (CCONJ)
#     still (ADV)
#     , (PUNCT)
#     faintly (ADV)
#
#  (SPACE)
#     marked (VERB)
#     with (ADP)
#     transverse (ADJ)
#     stripes (NOUN)
#     , (PUNCT)
#     and (CCONJ)
#     slightly (ADV)
#     flattened (VERB)
#     from (ADP)
#     the (DET)
#     perfect (ADJ)
#
#  (SPACE)
#     round (NOUN)
#     . (PUNCT)
#     But (CCONJ)
#     so (ADV)
#     little (ADJ)
#     it (PRON)
#     was (AUX)
#     , (PUNCT)
#     so (ADV)
#     silvery (ADV)
#     warm (ADJ)
#     — (PUNCT)
#     a (DET)
#     pin (NOUN)
#     ’s (PART)
#     head (NOUN)
#     of (ADP)
#     light (NOUN)
#     ! (PUNCT)
#     It (PRON)
#
#  (SPACE)
#     was (AUX)
#     as (SCONJ)
#     if (SCONJ)
#     it (PRON)
#     quivered (VERB)
#     , (PUNCT)
#     but (CCONJ)
#     really (ADV)
#     this (PRON)
#     was (AUX)
#     the (DET)
#     telescope (NOUN)
#     vibrating (VERB)
#     with (ADP)
#
#  (SPACE)
#     the (DET)
#     activity (NOUN)
#     of (ADP)
#     the (DET)
#     clockwork (NOUN)
#     that (PRON)
#     kept (VERB)
#     the (DET)
#     planet (NOUN)
#     in (ADP)
#     view (NOUN)
#     . (PUNCT)
#
#
#  (SPACE)
#     As (SCONJ)
#     I (PRON)
#     watched (VERB)
#     , (PUNCT)
#     the (DET)
#     planet (NOUN)
#     seemed (VERB)
#     to (PART)
#     grow (VERB)
#     larger (ADJ)
#     and (CCONJ)
#     smaller (ADJ)
#     and (CCONJ)
#     to (PART)
#
#  (SPACE)
#     advance (VERB)
#     and (CCONJ)
#     recede (VERB)
#     , (PUNCT)
#     but (CCONJ)
#     that (PRON)
#     was (AUX)
#     simply (ADV)
#     that (SCONJ)
#     my (PRON)
#     eye (NOUN)
#     was (AUX)
#     tired (ADJ)
#     . (PUNCT)
#     Forty (NUM)
#
#  (SPACE)
#     millions (NOUN)
#     of (ADP)
#     miles (NOUN)
#     it (PRON)
#     was (AUX)
#     from (ADP)
#     us (PRON)
#     — (PUNCT)
#     more (ADJ)
#     than (ADP)
#     forty (NUM)
#     millions (NOUN)
#     of (ADP)
#     miles (NOUN)
#     of (ADP)
#
#  (SPACE)
#     void (ADJ)
#     . (PUNCT)
#     Few (ADJ)
#     people (NOUN)
#     realise (VERB)
#     the (DET)
#     immensity (NOUN)
#     of (ADP)
#     vacancy (NOUN)
#     in (ADP)
#     which (PRON)
#     the (DET)
#     dust (NOUN)
#     of (ADP)
#
#  (SPACE)
#     the (DET)
#     material (ADJ)
#     universe (NOUN)
#     swims (VERB)
#     . (PUNCT)
#
#
#  (SPACE)
#     Near (ADP)
#     it (PRON)
#     in (ADP)
#     the (DET)
#     field (NOUN)
#     , (PUNCT)
#     I (PRON)
#     remember (VERB)
#     , (PUNCT)
#     were (AUX)
#     three (NUM)
#     faint (ADJ)
#     points (NOUN)
#     of (ADP)
#     light (NOUN)
#     , (PUNCT)
#
#  (SPACE)
#     three (NUM)
#     telescopic (ADJ)
#     stars (NOUN)
#     infinitely (ADV)
#     remote (VERB)
#     , (PUNCT)
#     and (CCONJ)
#     all (ADV)
#     around (ADP)
#     it (PRON)
#     was (AUX)
#     the (DET)
#
#  (SPACE)
#     unfathomable (ADJ)
#     darkness (NOUN)
#     of (ADP)
#     empty (ADJ)
#     space (NOUN)
#     . (PUNCT)
#     You (PRON)
#     know (VERB)
#     how (SCONJ)
#     that (SCONJ)
#     blackness (NOUN)
#     looks (VERB)
#
#  (SPACE)
#     on (ADP)
#     a (DET)
#     frosty (ADJ)
#     starlight (ADJ)
#     night (NOUN)
#     . (PUNCT)
#     In (ADP)
#     a (DET)
#     telescope (NOUN)
#     it (PRON)
#     seems (VERB)
#     far (ADV)
#     profounder (NOUN)
#     . (PUNCT)
#
#  (SPACE)
#     And (CCONJ)
#     invisible (ADJ)
#     to (ADP)
#     me (PRON)
#     because (SCONJ)
#     it (PRON)
#     was (AUX)
#     so (ADV)
#     remote (ADJ)
#     and (CCONJ)
#     small (ADJ)
#     , (PUNCT)
#     flying (VERB)
#     swiftly (ADV)
#
#  (SPACE)
#     and (CCONJ)
#     steadily (ADV)
#     towards (ADP)
#     me (PRON)
#     across (ADP)
#     that (DET)
#     incredible (ADJ)
#     distance (NOUN)
#     , (PUNCT)
#     drawing (VERB)
#     nearer (NOUN)
#
#  (SPACE)
#     every (DET)
#     minute (NOUN)
#     by (ADP)
#     so (ADV)
#     many (ADJ)
#     thousands (NOUN)
#     of (ADP)
#     miles (NOUN)
#     , (PUNCT)
#     came (VERB)
#     the (DET)
#     Thing (NOUN)
#     they (PRON)
#     were (AUX)
#
#  (SPACE)
#     sending (VERB)
#     us (PRON)
#     , (PUNCT)
#     the (DET)
#     Thing (NOUN)
#     that (PRON)
#     was (AUX)
#     to (PART)
#     bring (VERB)
#     so (ADV)
#     much (ADJ)
#     struggle (NOUN)
#     and (CCONJ)
#     calamity (NOUN)
#
#  (SPACE)
#     and (CCONJ)
#     death (NOUN)
#     to (ADP)
#     the (DET)
#     earth (NOUN)
#     . (PUNCT)
#     I (PRON)
#     never (ADV)
#     dreamed (VERB)
#     of (ADP)
#     it (PRON)
#     then (ADV)
#     as (SCONJ)
#     I (PRON)
#     watched (VERB)
#     ; (PUNCT)
#     no (DET)
#     one (NOUN)
#
#  (SPACE)
#     on (ADP)
#     earth (NOUN)
#     dreamed (VERB)
#     of (ADP)
#     that (DET)
#     unerring (VERB)
#     missile (NOUN)
#     . (PUNCT)
#
#
#  (SPACE)
#     That (DET)
#     night (NOUN)
#     , (PUNCT)
#     too (ADV)
#     , (PUNCT)
#     there (PRON)
#     was (VERB)
#     another (DET)
#     jetting (NOUN)
#     out (ADP)
#     of (ADP)
#     gas (NOUN)
#     from (ADP)
#     the (DET)
#     distant (ADJ)
#
#  (SPACE)
#     planet (NOUN)
#     . (PUNCT)
#     I (PRON)
#     saw (VERB)
#     it (PRON)
#     . (PUNCT)
#     A (DET)
#     reddish (ADJ)
#     flash (NOUN)
#     at (ADP)
#     the (DET)
#     edge (NOUN)
#     , (PUNCT)
#     the (DET)
#     slightest (ADJ)
#     projection (NOUN)
#
#  (SPACE)
#     of (ADP)
#     the (DET)
#     outline (NOUN)
#     just (ADV)
#     as (SCONJ)
#     the (DET)
#     chronometer (NOUN)
#     struck (VERB)
#     midnight (NOUN)
#     ; (PUNCT)
#     and (CCONJ)
#     at (ADP)
#     that (PRON)
#     I (PRON)
#
#  (SPACE)
#     told (VERB)
#     Ogilvy (PROPN)
#     and (CCONJ)
#     he (PRON)
#     took (VERB)
#     my (PRON)
#     place (NOUN)
#     . (PUNCT)
#     The (DET)
#     night (NOUN)
#     was (AUX)
#     warm (ADJ)
#     and (CCONJ)
#     I (PRON)
#     was (AUX)
#     thirsty (ADJ)
#     , (PUNCT)
#
#  (SPACE)
#     and (CCONJ)
#     I (PRON)
#     went (VERB)
#     stretching (VERB)
#     my (PRON)
#     legs (NOUN)
#     clumsily (ADV)
#     and (CCONJ)
#     feeling (VERB)
#     my (PRON)
#     way (NOUN)
#     in (ADP)
#     the (DET)
#
#  (SPACE)
#     darkness (NOUN)
#     , (PUNCT)
#     to (ADP)
#     the (DET)
#     little (ADJ)
#     table (NOUN)
#     where (SCONJ)
#     the (DET)
#     siphon (PROPN)
#     stood (VERB)
#     , (PUNCT)
#     while (SCONJ)
#     Ogilvy (PROPN)
#
#  (SPACE)
#     exclaimed (VERB)
#     at (ADP)
#     the (DET)
#     streamer (NOUN)
#     of (ADP)
#     gas (NOUN)
#     that (PRON)
#     came (VERB)
#     out (ADP)
#     towards (ADP)
#     us (PRON)
#     . (PUNCT)
#
#
#  (SPACE)
#     That (DET)
#     night (NOUN)
#     another (DET)
#     invisible (ADJ)
#     missile (NOUN)
#     started (VERB)
#     on (ADP)
#     its (PRON)
#     way (NOUN)
#     to (ADP)
#     the (DET)
#     earth (NOUN)
#
#  (SPACE)
#     from (ADP)
#     Mars (PROPN)
#     , (PUNCT)
#     just (ADV)
#     a (DET)
#     second (ADJ)
#     or (CCONJ)
#     so (ADV)
#     under (ADP)
#     twenty (NUM)
#     - (PUNCT)
#     four (NUM)
#     hours (NOUN)
#     after (ADP)
#     the (DET)
#     first (ADJ)
#
#  (SPACE)
#     one (NUM)
#     . (PUNCT)
#     I (PRON)
#     remember (VERB)
#     how (SCONJ)
#     I (PRON)
#     sat (VERB)
#     on (ADP)
#     the (DET)
#     table (NOUN)
#     there (ADV)
#     in (ADP)
#     the (DET)
#     blackness (NOUN)
#     , (PUNCT)
#     with (ADP)
#
#  (SPACE)
#     patches (NOUN)
#     of (ADP)
#     green (ADJ)
#     and (CCONJ)
#     crimson (ADJ)
#     swimming (NOUN)
#     before (ADP)
#     my (PRON)
#     eyes (NOUN)
#     . (PUNCT)
#     I (PRON)
#     wished (VERB)
#     I (PRON)
#     had (VERB)
#     a (DET)
#
#  (SPACE)
#     light (NOUN)
#     to (PART)
#     smoke (VERB)
#     by (ADP)
#     , (PUNCT)
#     little (ADJ)
#     suspecting (NOUN)
#     the (DET)
#     meaning (NOUN)
#     of (ADP)
#     the (DET)
#     minute (NOUN)
#     gleam (NOUN)
#     I (PRON)
#
#  (SPACE)
#     had (AUX)
#     seen (VERB)
#     and (CCONJ)
#     all (PRON)
#     that (PRON)
#     it (PRON)
#     would (AUX)
#     presently (ADV)
#     bring (VERB)
#     me (PRON)
#     . (PUNCT)
#     Ogilvy (PROPN)
#     watched (VERB)
#     till (SCONJ)
#
#  (SPACE)
#     one (NUM)
#     , (PUNCT)
#     and (CCONJ)
#     then (ADV)
#     gave (VERB)
#     it (PRON)
#     up (ADP)
#     ; (PUNCT)
#     and (CCONJ)
#     we (PRON)
#     lit (VERB)
#     the (DET)
#     lantern (NOUN)
#     and (CCONJ)
#     walked (VERB)
#     over (ADV)
#     to (ADP)
#     his (PRON)
#
#  (SPACE)
#     house (NOUN)
#     . (PUNCT)
#     Down (ADV)
#     below (ADV)
#     in (ADP)
#     the (DET)
#     darkness (NOUN)
#     were (AUX)
#     Ottershaw (PROPN)
#     and (CCONJ)
#     Chertsey (PROPN)
#     and (CCONJ)
#     all (DET)
#
#  (SPACE)
#     their (PRON)
#     hundreds (NOUN)
#     of (ADP)
#     people (NOUN)
#     , (PUNCT)
#     sleeping (VERB)
#     in (ADP)
#     peace (NOUN)
#     . (PUNCT)
#
#
#  (SPACE)
#     He (PRON)
#     was (AUX)
#     full (ADJ)
#     of (ADP)
#     speculation (NOUN)
#     that (DET)
#     night (NOUN)
#     about (ADP)
#     the (DET)
#     condition (NOUN)
#     of (ADP)
#     Mars (PROPN)
#     , (PUNCT)
#     and (CCONJ)
#
#  (SPACE)
#     scoffed (VERB)
#     at (ADP)
#     the (DET)
#     vulgar (ADJ)
#     idea (NOUN)
#     of (ADP)
#     its (PRON)
#     having (VERB)
#     inhabitants (NOUN)
#     who (PRON)
#     were (AUX)
#
#  (SPACE)
#     signalling (VERB)
#     us (PRON)
#     . (PUNCT)
#     His (PRON)
#     idea (NOUN)
#     was (AUX)
#     that (SCONJ)
#     meteorites (NOUN)
#     might (AUX)
#     be (AUX)
#     falling (VERB)
#     in (ADP)
#     a (DET)
#     heavy (ADJ)
#
#  (SPACE)
#     shower (NOUN)
#     upon (SCONJ)
#     the (DET)
#     planet (NOUN)
#     , (PUNCT)
#     or (CCONJ)
#     that (SCONJ)
#     a (DET)
#     huge (ADJ)
#     volcanic (ADJ)
#     explosion (NOUN)
#     was (AUX)
#     in (ADP)
#
#  (SPACE)
#     progress (NOUN)
#     . (PUNCT)
#     He (PRON)
#     pointed (VERB)
#     out (ADP)
#     to (ADP)
#     me (PRON)
#     how (SCONJ)
#     unlikely (ADJ)
#     it (PRON)
#     was (AUX)
#     that (SCONJ)
#     organic (ADJ)
#
#  (SPACE)
#     evolution (NOUN)
#     had (AUX)
#     taken (VERB)
#     the (DET)
#     same (ADJ)
#     direction (NOUN)
#     in (ADP)
#     the (DET)
#     two (NUM)
#     adjacent (ADJ)
#     planets (NOUN)
#     . (PUNCT)
#
#
#  (SPACE)
#     “ (PUNCT)
#     The (DET)
#     chances (NOUN)
#     against (ADP)
#     anything (PRON)
#     manlike (ADJ)
#     on (ADP)
#     Mars (PROPN)
#     are (AUX)
#     a (DET)
#     million (NUM)
#     to (ADP)
#     one (NUM)
#     , (PUNCT)
#     ” (PUNCT)
#     he (PRON)
#
#  (SPACE)
#     said (VERB)
#     . (PUNCT)
#
#
#  (SPACE)
#     Hundreds (NOUN)
#     of (ADP)
#     observers (NOUN)
#     saw (VERB)
#     the (DET)
#     flame (NOUN)
#     that (DET)
#     night (NOUN)
#     and (CCONJ)
#     the (DET)
#     night (NOUN)
#     after (ADP)
#
#  (SPACE)
#     about (ADV)
#     midnight (NOUN)
#     , (PUNCT)
#     and (CCONJ)
#     again (ADV)
#     the (DET)
#     night (NOUN)
#     after (ADP)
#     ; (PUNCT)
#     and (CCONJ)
#     so (ADV)
#     for (ADP)
#     ten (NUM)
#     nights (NOUN)
#     , (PUNCT)
#     a (DET)
#
#  (SPACE)
#     flame (NOUN)
#     each (DET)
#     night (NOUN)
#     . (PUNCT)
#     Why (SCONJ)
#     the (DET)
#     shots (NOUN)
#     ceased (VERB)
#     after (ADP)
#     the (DET)
#     tenth (NOUN)
#     no (DET)
#     one (NOUN)
#     on (ADP)
#     earth (NOUN)
#
#  (SPACE)
#     has (AUX)
#     attempted (VERB)
#     to (PART)
#     explain (VERB)
#     . (PUNCT)
#     It (PRON)
#     may (AUX)
#     be (AUX)
#     the (DET)
#     gases (NOUN)
#     of (ADP)
#     the (DET)
#     firing (NOUN)
#     caused (VERB)
#     the (DET)
#
#  (SPACE)
#     Martians (PROPN)
#     inconvenience (NOUN)
#     . (PUNCT)
#     Dense (ADJ)
#     clouds (NOUN)
#     of (ADP)
#     smoke (NOUN)
#     or (CCONJ)
#     dust (NOUN)
#     , (PUNCT)
#     visible (ADJ)
#     through (ADP)
#
#  (SPACE)
#     a (DET)
#     powerful (ADJ)
#     telescope (NOUN)
#     on (ADP)
#     earth (NOUN)
#     as (ADP)
#     little (ADJ)
#     grey (NOUN)
#     , (PUNCT)
#     fluctuating (NOUN)
#     patches (NOUN)
#     , (PUNCT)
#
#  (SPACE)
#     spread (VERB)
#     through (ADP)
#     the (DET)
#     clearness (NOUN)
#     of (ADP)
#     the (DET)
#     planet (NOUN)
#     ’s (PART)
#     atmosphere (NOUN)
#     and (CCONJ)
#     obscured (VERB)
#
#  (SPACE)
#     its (PRON)
#     more (ADV)
#     familiar (ADJ)
#     features (NOUN)
#     . (PUNCT)
#
#
#  (SPACE)
#     Even (ADV)
#     the (DET)
#     daily (ADJ)
#     papers (NOUN)
#     woke (VERB)
#     up (ADP)
#     to (ADP)
#     the (DET)
#     disturbances (NOUN)
#     at (ADP)
#     last (ADJ)
#     , (PUNCT)
#     and (CCONJ)
#     popular (ADJ)
#
#  (SPACE)
#     notes (NOUN)
#     appeared (VERB)
#     here (ADV)
#     , (PUNCT)
#     there (ADV)
#     , (PUNCT)
#     and (CCONJ)
#     everywhere (ADV)
#     concerning (VERB)
#     the (DET)
#     volcanoes (NOUN)
#
#  (SPACE)
#     upon (SCONJ)
#     Mars (PROPN)
#     . (PUNCT)
#     The (DET)
#     seriocomic (ADJ)
#     periodical (NOUN)
#     _ (PUNCT)
#     Punch (VERB)
#     _ (NOUN)
#     , (PUNCT)
#     I (PRON)
#     remember (VERB)
#     , (PUNCT)
#     made (VERB)
#     a (DET)
#     happy (ADJ)
#
#  (SPACE)
#     use (NOUN)
#     of (ADP)
#     it (PRON)
#     in (ADP)
#     the (DET)
#     political (ADJ)
#     cartoon (NOUN)
#     . (PUNCT)
#     And (CCONJ)
#     , (PUNCT)
#     all (PRON)
#     unsuspected (ADJ)
#     , (PUNCT)
#     those (DET)
#
#  (SPACE)
#     missiles (NOUN)
#     the (DET)
#     Martians (PROPN)
#     had (AUX)
#     fired (VERB)
#     at (ADP)
#     us (PRON)
#     drew (VERB)
#     earthward (NOUN)
#     , (PUNCT)
#     rushing (VERB)
#     now (ADV)
#     at (ADP)
#     a (DET)
#
#  (SPACE)
#     pace (NOUN)
#     of (ADP)
#     many (ADJ)
#     miles (NOUN)
#     a (DET)
#     second (NOUN)
#     through (ADP)
#     the (DET)
#     empty (ADJ)
#     gulf (NOUN)
#     of (ADP)
#     space (NOUN)
#     , (PUNCT)
#     hour (NOUN)
#     by (ADP)
#
#  (SPACE)
#     hour (NOUN)
#     and (CCONJ)
#     day (NOUN)
#     by (ADP)
#     day (NOUN)
#     , (PUNCT)
#     nearer (ADJ)
#     and (CCONJ)
#     nearer (NOUN)
#     . (PUNCT)
#     It (PRON)
#     seems (VERB)
#     to (ADP)
#     me (PRON)
#     now (ADV)
#     almost (ADV)
#
#  (SPACE)
#     incredibly (ADV)
#     wonderful (ADJ)
#     that (SCONJ)
#     , (PUNCT)
#     with (ADP)
#     that (DET)
#     swift (ADJ)
#     fate (NOUN)
#     hanging (VERB)
#     over (ADP)
#     us (PRON)
#     , (PUNCT)
#     men (NOUN)
#
#  (SPACE)
#     could (AUX)
#     go (VERB)
#     about (ADP)
#     their (PRON)
#     petty (ADJ)
#     concerns (NOUN)
#     as (SCONJ)
#     they (PRON)
#     did (VERB)
#     . (PUNCT)
#     I (PRON)
#     remember (VERB)
#     how (SCONJ)
#
#  (SPACE)
#     jubilant (ADJ)
#     Markham (PROPN)
#     was (AUX)
#     at (ADP)
#     securing (VERB)
#     a (DET)
#     new (ADJ)
#     photograph (NOUN)
#     of (ADP)
#     the (DET)
#     planet (NOUN)
#     for (ADP)
#     the (DET)
#
#  (SPACE)
#     illustrated (VERB)
#     paper (NOUN)
#     he (PRON)
#     edited (VERB)
#     in (ADP)
#     those (DET)
#     days (NOUN)
#     . (PUNCT)
#     People (NOUN)
#     in (ADP)
#     these (DET)
#     latter (ADJ)
#     times (NOUN)
#
#  (SPACE)
#     scarcely (ADV)
#     realise (VERB)
#     the (DET)
#     abundance (NOUN)
#     and (CCONJ)
#     enterprise (NOUN)
#     of (ADP)
#     our (PRON)
#     nineteenth (ADJ)
#     - (PUNCT)
#     century (NOUN)
#
#  (SPACE)
#     papers (NOUN)
#     . (PUNCT)
#     For (ADP)
#     my (PRON)
#     own (ADJ)
#     part (NOUN)
#     , (PUNCT)
#     I (PRON)
#     was (AUX)
#     much (ADV)
#     occupied (VERB)
#     in (ADP)
#     learning (VERB)
#     to (PART)
#     ride (VERB)
#     the (DET)
#
#  (SPACE)
#     bicycle (NOUN)
#     , (PUNCT)
#     and (CCONJ)
#     busy (ADJ)
#     upon (SCONJ)
#     a (DET)
#     series (NOUN)
#     of (ADP)
#     papers (NOUN)
#     discussing (VERB)
#     the (DET)
#     probable (ADJ)
#
#  (SPACE)
#     developments (NOUN)
#     of (ADP)
#     moral (ADJ)
#     ideas (NOUN)
#     as (SCONJ)
#     civilisation (NOUN)
#     progressed (VERB)
#     . (PUNCT)
#
#
#  (SPACE)
#     One (NUM)
#     night (NOUN)
#     ( (PUNCT)
#     the (DET)
#     first (ADJ)
#     missile (NOUN)
#     then (ADV)
#     could (AUX)
#     scarcely (ADV)
#     have (AUX)
#     been (AUX)
#     10,000,000 (NUM)
#
#  (SPACE)
#     miles (NOUN)
#     away (ADV)
#     ) (PUNCT)
#     I (PRON)
#     went (VERB)
#     for (ADP)
#     a (DET)
#     walk (NOUN)
#     with (ADP)
#     my (PRON)
#     wife (NOUN)
#     . (PUNCT)
#     It (PRON)
#     was (AUX)
#     starlight (ADJ)
#     and (CCONJ)
#     I (PRON)
#
#  (SPACE)
#     explained (VERB)
#     the (DET)
#     Signs (PROPN)
#     of (ADP)
#     the (DET)
#     Zodiac (PROPN)
#     to (ADP)
#     her (PRON)
#     , (PUNCT)
#     and (CCONJ)
#     pointed (VERB)
#     out (ADP)
#     Mars (PROPN)
#     , (PUNCT)
#     a (DET)
#
#  (SPACE)
#     bright (ADJ)
#     dot (NOUN)
#     of (ADP)
#     light (NOUN)
# ...
#     provisions (NOUN)
#     . (PUNCT)
#
#
#  (SPACE)
#     1.F.6 (PROPN)
#     . (PUNCT)
#     INDEMNITY (PROPN)
#     - (PUNCT)
#     You (PRON)
#     agree (VERB)
#     to (PART)
#     indemnify (VERB)
#     and (CCONJ)
#     hold (VERB)
#     the (DET)
#     Foundation (PROPN)
#     , (PUNCT)
#     the (DET)
#
#  (SPACE)
#     trademark (NOUN)
#     owner (NOUN)
#     , (PUNCT)
#     any (DET)
#     agent (NOUN)
#     or (CCONJ)
#     employee (NOUN)
#     of (ADP)
#     the (DET)
#     Foundation (PROPN)
#     , (PUNCT)
#     anyone (PRON)
#
#  (SPACE)
#     providing (VERB)
#     copies (NOUN)
#     of (ADP)
#     Project (PROPN)
#     Gutenberg (PROPN)
#     ™ (PUNCT)
#     electronic (ADJ)
#     works (NOUN)
#     in (ADP)
#
#  (SPACE)
#     accordance (NOUN)
#     with (ADP)
#     this (DET)
#     agreement (NOUN)
#     , (PUNCT)
#     and (CCONJ)
#     any (DET)
#     volunteers (NOUN)
#     associated (VERB)
#     with (ADP)
#     the (DET)
#
#  (SPACE)
#     production (NOUN)
#     , (PUNCT)
#     promotion (NOUN)
#     and (CCONJ)
#     distribution (NOUN)
#     of (ADP)
#     Project (PROPN)
#     Gutenberg (PROPN)
#     ™ (PUNCT)
#
#  (SPACE)
#     electronic (ADJ)
#     works (NOUN)
#     , (PUNCT)
#     harmless (ADJ)
#     from (ADP)
#     all (DET)
#     liability (NOUN)
#     , (PUNCT)
#     costs (NOUN)
#     and (CCONJ)
#     expenses (NOUN)
#     , (PUNCT)
#
#  (SPACE)
#     including (VERB)
#     legal (ADJ)
#     fees (NOUN)
#     , (PUNCT)
#     that (PRON)
#     arise (VERB)
#     directly (ADV)
#     or (CCONJ)
#     indirectly (ADV)
#     from (ADP)
#     any (PRON)
#     of (ADP)
#
#  (SPACE)
#     the (DET)
#     following (NOUN)
#     which (PRON)
#     you (PRON)
#     do (VERB)
#     or (CCONJ)
#     cause (VERB)
#     to (PART)
#     occur (VERB)
#     : (PUNCT)
#     ( (PUNCT)
#     a (DET)
#     ) (PUNCT)
#     distribution (NOUN)
#     of (ADP)
#     this (PRON)
#
#  (SPACE)
#     or (CCONJ)
#     any (DET)
#     Project (PROPN)
#     Gutenberg (PROPN)
#     ™ (NOUN)
#     work (NOUN)
#     , (PUNCT)
#     ( (PUNCT)
#     b (PROPN)
#     ) (PUNCT)
#     alteration (NOUN)
#     , (PUNCT)
#     modification (NOUN)
#     , (PUNCT)
#     or (CCONJ)
#
#  (SPACE)
#     additions (NOUN)
#     or (CCONJ)
#     deletions (NOUN)
#     to (ADP)
#     any (DET)
#     Project (PROPN)
#     Gutenberg (PROPN)
#     ™ (NOUN)
#     work (NOUN)
#     , (PUNCT)
#     and (CCONJ)
#     ( (PUNCT)
#     c (NOUN)
#     ) (PUNCT)
#     any (DET)
#
#  (SPACE)
#     Defect (PROPN)
#     you (PRON)
#     cause (VERB)
#     . (PUNCT)
#
#
#  (SPACE)
#     Section (NOUN)
#     2 (NUM)
#     . (X)
#     Information (NOUN)
#     about (ADP)
#     the (DET)
#     Mission (PROPN)
#     of (ADP)
#     Project (PROPN)
#     Gutenberg (PROPN)
#     ™ (PUNCT)
#
#
#  (SPACE)
#     Project (PROPN)
#     Gutenberg (PROPN)
#     ™ (X)
#     is (AUX)
#     synonymous (ADJ)
#     with (ADP)
#     the (DET)
#     free (ADJ)
#     distribution (NOUN)
#     of (ADP)
#
#  (SPACE)
#     electronic (ADJ)
#     works (NOUN)
#     in (ADP)
#     formats (NOUN)
#     readable (ADJ)
#     by (ADP)
#     the (DET)
#     widest (ADJ)
#     variety (NOUN)
#     of (ADP)
#
#  (SPACE)
#     computers (NOUN)
#     including (VERB)
#     obsolete (ADJ)
#     , (PUNCT)
#     old (ADJ)
#     , (PUNCT)
#     middle (ADJ)
#     - (PUNCT)
#     aged (ADJ)
#     and (CCONJ)
#     new (ADJ)
#     computers (NOUN)
#     . (PUNCT)
#     It (PRON)
#
#  (SPACE)
#     exists (VERB)
#     because (SCONJ)
#     of (ADP)
#     the (DET)
#     efforts (NOUN)
#     of (ADP)
#     hundreds (NOUN)
#     of (ADP)
#     volunteers (NOUN)
#     and (CCONJ)
#     donations (NOUN)
#
#  (SPACE)
#     from (ADP)
#     people (NOUN)
#     in (ADP)
#     all (DET)
#     walks (NOUN)
#     of (ADP)
#     life (NOUN)
#     . (PUNCT)
#
#
#  (SPACE)
#     Volunteers (NOUN)
#     and (CCONJ)
#     financial (ADJ)
#     support (NOUN)
#     to (PART)
#     provide (VERB)
#     volunteers (NOUN)
#     with (ADP)
#     the (DET)
#
#  (SPACE)
#     assistance (NOUN)
#     they (PRON)
#     need (VERB)
#     are (AUX)
#     critical (ADJ)
#     to (ADP)
#     reaching (VERB)
#     Project (PROPN)
#     Gutenberg (PROPN)
#     ™ (X)
#     ’s (PART)
#
#  (SPACE)
#     goals (NOUN)
#     and (CCONJ)
#     ensuring (VERB)
#     that (SCONJ)
#     the (DET)
#     Project (PROPN)
#     Gutenberg (PROPN)
#     ™ (NOUN)
#     collection (NOUN)
#     will (AUX)
#
#  (SPACE)
#     remain (VERB)
#     freely (ADV)
#     available (ADJ)
#     for (SCONJ)
#     generations (NOUN)
#     to (PART)
#     come (VERB)
#     . (PUNCT)
#     In (ADP)
#     2001 (NUM)
#     , (PUNCT)
#     the (DET)
#     Project (PROPN)
#
#  (SPACE)
#     Gutenberg (PROPN)
#     Literary (PROPN)
#     Archive (PROPN)
#     Foundation (PROPN)
#     was (AUX)
#     created (VERB)
#     to (PART)
#     provide (VERB)
#     a (DET)
#     secure (ADJ)
#
#  (SPACE)
#     and (CCONJ)
#     permanent (ADJ)
#     future (NOUN)
#     for (ADP)
#     Project (PROPN)
#     Gutenberg (PROPN)
#     ™ (PUNCT)
#     and (CCONJ)
#     future (NOUN)
#
#  (SPACE)
#     generations (NOUN)
#     . (PUNCT)
#     To (PART)
#     learn (VERB)
#     more (ADJ)
#     about (ADP)
#     the (DET)
#     Project (PROPN)
#     Gutenberg (PROPN)
#     Literary (PROPN)
#
#  (SPACE)
#     Archive (PROPN)
#     Foundation (PROPN)
#     and (CCONJ)
#     how (SCONJ)
#     your (PRON)
#     efforts (NOUN)
#     and (CCONJ)
#     donations (NOUN)
#     can (AUX)
#     help (VERB)
#     , (PUNCT)
#     see (VERB)
#
#  (SPACE)
#     Sections (NOUN)
#     3 (NUM)
#     and (CCONJ)
#     4 (NUM)
#     and (CCONJ)
#     the (DET)
#     Foundation (PROPN)
#     information (NOUN)
#     page (NOUN)
#     at (ADP)
#     www.gutenberg.org (NUM)
#     . (PUNCT)
#
#
#  (SPACE)
#     Section (PROPN)
#     3 (NUM)
#     . (PUNCT)
#     Information (NOUN)
#     about (ADP)
#     the (DET)
#     Project (PROPN)
#     Gutenberg (PROPN)
#     Literary (PROPN)
#     Archive (PROPN)
#     Foundation (PROPN)
#
#
#  (SPACE)
#     The (DET)
#     Project (PROPN)
#     Gutenberg (PROPN)
#     Literary (PROPN)
#     Archive (PROPN)
#     Foundation (PROPN)
#     is (AUX)
#     a (DET)
#     non (ADJ)
#     - (ADJ)
#     profit (ADJ)
#
#  (SPACE)
#     501(c)(3 (NOUN)
#     ) (PUNCT)
#     educational (ADJ)
#     corporation (NOUN)
#     organized (VERB)
#     under (ADP)
#     the (DET)
#     laws (NOUN)
#     of (ADP)
#     the (DET)
#
#  (SPACE)
#     state (NOUN)
#     of (ADP)
#     Mississippi (PROPN)
#     and (CCONJ)
#     granted (VERB)
#     tax (NOUN)
#     exempt (ADJ)
#     status (NOUN)
#     by (ADP)
#     the (DET)
#     Internal (PROPN)
#
#  (SPACE)
#     Revenue (PROPN)
#     Service (PROPN)
#     . (PUNCT)
#     The (DET)
#     Foundation (PROPN)
#     ’s (PART)
#     EIN (PROPN)
#     or (CCONJ)
#     federal (ADJ)
#     tax (NOUN)
#     identification (NOUN)
#
#  (SPACE)
#     number (NOUN)
#     is (AUX)
#     64 (NUM)
#     - (SYM)
#     6221541 (NUM)
#     . (PUNCT)
#     Contributions (NOUN)
#     to (ADP)
#     the (DET)
#     Project (PROPN)
#     Gutenberg (PROPN)
#     Literary (PROPN)
#
#  (SPACE)
#     Archive (PROPN)
#     Foundation (PROPN)
#     are (AUX)
#     tax (NOUN)
#     deductible (ADJ)
#     to (ADP)
#     the (DET)
#     full (ADJ)
#     extent (NOUN)
#     permitted (VERB)
#     by (ADP)
#
#  (SPACE)
#     U.S. (PROPN)
#     federal (ADJ)
#     laws (NOUN)
#     and (CCONJ)
#     your (PRON)
#     state (NOUN)
#     ’s (PART)
#     laws (NOUN)
#     . (PUNCT)
#
#
#  (SPACE)
#     The (DET)
#     Foundation (PROPN)
#     ’s (PART)
#     business (NOUN)
#     office (NOUN)
#     is (AUX)
#     located (VERB)
#     at (ADP)
#     809 (NUM)
#     North (PROPN)
#     1500 (NUM)
#     West (PROPN)
#     , (PUNCT)
#
#  (SPACE)
#     Salt (PROPN)
#     Lake (PROPN)
#     City (PROPN)
#     , (PUNCT)
#     UT (PROPN)
#     84116 (NUM)
#     , (PUNCT)
#     ( (PUNCT)
#     801 (NUM)
#     ) (PUNCT)
#     596 (NUM)
#     - (SYM)
#     1887 (NUM)
#     . (PUNCT)
#     Email (NOUN)
#     contact (NOUN)
#     links (NOUN)
#     and (CCONJ)
#     up (ADV)
#
#  (SPACE)
#     to (ADP)
#     date (NOUN)
#     contact (NOUN)
#     information (NOUN)
#     can (AUX)
#     be (AUX)
#     found (VERB)
#     at (ADP)
#     the (DET)
#     Foundation (PROPN)
#     ’s (PART)
#     website (NOUN)
#
#  (SPACE)
#     and (CCONJ)
#     official (ADJ)
#     page (NOUN)
#     at (ADP)
#     www.gutenberg.org/contact (NOUN)
#
#
#  (SPACE)
#     Section (NOUN)
#     4 (NUM)
#     . (PUNCT)
#     Information (NOUN)
#     about (ADP)
#     Donations (NOUN)
#     to (ADP)
#     the (DET)
#     Project (PROPN)
#     Gutenberg (PROPN)
#
#  (SPACE)
#     Literary (PROPN)
#     Archive (PROPN)
#     Foundation (PROPN)
#
#
#  (SPACE)
#     Project (PROPN)
#     Gutenberg (PROPN)
#     ™ (X)
#     depends (VERB)
#     upon (SCONJ)
#     and (CCONJ)
#     can (AUX)
#     not (PART)
#     survive (VERB)
#     without (ADP)
#     widespread (ADJ)
#
#  (SPACE)
#     public (ADJ)
#     support (NOUN)
#     and (CCONJ)
#     donations (NOUN)
#     to (PART)
#     carry (VERB)
#     out (ADP)
#     its (PRON)
#     mission (NOUN)
#     of (ADP)
#
#  (SPACE)
#     increasing (VERB)
#     the (DET)
#     number (NOUN)
#     of (ADP)
#     public (ADJ)
#     domain (NOUN)
#     and (CCONJ)
#     licensed (VERB)
#     works (NOUN)
#     that (PRON)
#     can (AUX)
#     be (AUX)
#
#  (SPACE)
#     freely (ADV)
#     distributed (VERB)
#     in (ADP)
#     machine (NOUN)
#     - (PUNCT)
#     readable (ADJ)
#     form (NOUN)
#     accessible (ADJ)
#     by (ADP)
#     the (DET)
#     widest (ADJ)
#
#  (SPACE)
#     array (NOUN)
#     of (ADP)
#     equipment (NOUN)
#     including (VERB)
#     outdated (ADJ)
#     equipment (NOUN)
#     . (PUNCT)
#     Many (ADJ)
#     small (ADJ)
#     donations (NOUN)
#
#  (SPACE)
#     ( (PUNCT)
#     $ (SYM)
#     1 (NUM)
#     to (PART)
#     $ (SYM)
#     5,000 (NUM)
#     ) (PUNCT)
#     are (AUX)
#     particularly (ADV)
#     important (ADJ)
#     to (ADP)
#     maintaining (VERB)
#     tax (NOUN)
#     exempt (ADJ)
#
#  (SPACE)
#     status (NOUN)
#     with (ADP)
#     the (DET)
#     IRS (PROPN)
#     . (PUNCT)
#
#
#  (SPACE)
#     The (DET)
#     Foundation (PROPN)
#     is (AUX)
#     committed (VERB)
#     to (ADP)
#     complying (VERB)
#     with (ADP)
#     the (DET)
#     laws (NOUN)
#     regulating (VERB)
#
#  (SPACE)
#     charities (NOUN)
#     and (CCONJ)
#     charitable (ADJ)
#     donations (NOUN)
#     in (ADP)
#     all (DET)
#     50 (NUM)
#     states (NOUN)
#     of (ADP)
#     the (DET)
#     United (PROPN)
#
#  (SPACE)
#     States (PROPN)
#     . (PUNCT)
#     Compliance (NOUN)
#     requirements (NOUN)
#     are (AUX)
#     not (PART)
#     uniform (ADJ)
#     and (CCONJ)
#     it (PRON)
#     takes (VERB)
#     a (DET)
#
#  (SPACE)
#     considerable (ADJ)
#     effort (NOUN)
#     , (PUNCT)
#     much (ADJ)
#     paperwork (NOUN)
#     and (CCONJ)
#     many (ADJ)
#     fees (NOUN)
#     to (PART)
#     meet (VERB)
#     and (CCONJ)
#     keep (VERB)
#     up (ADP)
#
#  (SPACE)
#     with (ADP)
#     these (DET)
#     requirements (NOUN)
#     . (PUNCT)
#     We (PRON)
#     do (AUX)
#     not (PART)
#     solicit (VERB)
#     donations (NOUN)
#     in (ADP)
#     locations (NOUN)
#
#  (SPACE)
#     where (SCONJ)
#     we (PRON)
#     have (AUX)
#     not (PART)
#     received (VERB)
#     written (VERB)
#     confirmation (NOUN)
#     of (ADP)
#     compliance (NOUN)
#     . (PUNCT)
#     To (ADP)
#     SEND (PROPN)
#
#  (SPACE)
#     DONATIONS (NOUN)
#     or (CCONJ)
#     determine (VERB)
#     the (DET)
#     status (NOUN)
#     of (ADP)
#     compliance (NOUN)
#     for (ADP)
#     any (DET)
#     particular (ADJ)
#     state (NOUN)
#
#  (SPACE)
#     visit (NOUN)
#     www.gutenberg.org/donate (NOUN)
#     . (PUNCT)
#
#
#  (SPACE)
#     While (SCONJ)
#     we (PRON)
#     can (AUX)
#     not (PART)
#     and (CCONJ)
#     do (AUX)
#     not (PART)
#     solicit (VERB)
#     contributions (NOUN)
#     from (ADP)
#     states (NOUN)
#     where (SCONJ)
#     we (PRON)
#
#  (SPACE)
#     have (AUX)
#     not (PART)
#     met (VERB)
#     the (DET)
#     solicitation (NOUN)
#     requirements (NOUN)
#     , (PUNCT)
#     we (PRON)
#     know (VERB)
#     of (ADP)
#     no (DET)
#     prohibition (NOUN)
#
#  (SPACE)
#     against (ADP)
#     accepting (VERB)
#     unsolicited (ADJ)
#     donations (NOUN)
#     from (ADP)
#     donors (NOUN)
#     in (ADP)
#     such (ADJ)
#     states (NOUN)
#     who (PRON)
#
#  (SPACE)
#     approach (VERB)
#     us (PRON)
#     with (ADP)
#     offers (NOUN)
#     to (PART)
#     donate (VERB)
#     . (PUNCT)
#
#
#  (SPACE)
#     International (ADJ)
#     donations (NOUN)
#     are (AUX)
#     gratefully (ADV)
#     accepted (VERB)
#     , (PUNCT)
#     but (CCONJ)
#     we (PRON)
#     can (AUX)
#     not (PART)
#     make (VERB)
#
#  (SPACE)
#     any (DET)
#     statements (NOUN)
#     concerning (VERB)
#     tax (NOUN)
#     treatment (NOUN)
#     of (ADP)
#     donations (NOUN)
#     received (VERB)
#     from (ADP)
#
#  (SPACE)
#     outside (ADP)
#     the (DET)
#     United (PROPN)
#     States (PROPN)
#     . (PUNCT)
#     U.S. (PROPN)
#     laws (NOUN)
#     alone (ADV)
#     swamp (VERB)
#     our (PRON)
#     small (ADJ)
#     staff (NOUN)
#     . (PUNCT)
#
#
#  (SPACE)
#     Please (INTJ)
#     check (VERB)
#     the (DET)
#     Project (PROPN)
#     Gutenberg (PROPN)
#     web (NOUN)
#     pages (NOUN)
#     for (ADP)
#     current (ADJ)
#     donation (NOUN)
#
#  (SPACE)
#     methods (NOUN)
#     and (CCONJ)
#     addresses (NOUN)
#     . (PUNCT)
#     Donations (NOUN)
#     are (AUX)
#     accepted (VERB)
#     in (ADP)
#     a (DET)
#     number (NOUN)
#     of (ADP)
#     other (ADJ)
#
#  (SPACE)
#     ways (NOUN)
#     including (VERB)
#     checks (NOUN)
#     , (PUNCT)
#     online (ADJ)
#     payments (NOUN)
#     and (CCONJ)
#     credit (NOUN)
#     card (NOUN)
#     donations (NOUN)
#     . (PUNCT)
#     To (PART)
#
#  (SPACE)
#     donate (VERB)
#     , (PUNCT)
#     please (INTJ)
#     visit (VERB)
#     : (PUNCT)
#     www.gutenberg.org/donate (NUM)
#     . (PUNCT)
#
#
#  (SPACE)
#     Section (NOUN)
#     5 (NUM)
#     . (PUNCT)
#     General (PROPN)
#     Information (PROPN)
#     About (PROPN)
#     Project (PROPN)
#     Gutenberg (PROPN)
#     ™ (X)
#     electronic (ADJ)
#     works (NOUN)
#
#
#  (SPACE)
#     Professor (PROPN)
#     Michael (PROPN)
#     S. (PROPN)
#     Hart (PROPN)
#     was (AUX)
#     the (DET)
#     originator (NOUN)
#     of (ADP)
#     the (DET)
#     Project (PROPN)
#
#  (SPACE)
#     Gutenberg (PROPN)
#     ™ (NOUN)
#     concept (NOUN)
#     of (ADP)
#     a (DET)
#     library (NOUN)
#     of (ADP)
#     electronic (ADJ)
#     works (NOUN)
#     that (PRON)
#     could (AUX)
#     be (AUX)
#
#  (SPACE)
#     freely (ADV)
#     shared (VERB)
#     with (ADP)
#     anyone (PRON)
#     . (PUNCT)
#     For (ADP)
#     forty (NUM)
#     years (NOUN)
#     , (PUNCT)
#     he (PRON)
#     produced (VERB)
#     and (CCONJ)
#
#  (SPACE)
#     distributed (VERB)
#     Project (PROPN)
#     Gutenberg (PROPN)
#     ™ (PUNCT)
#     eBooks (PROPN)
#     with (ADP)
#     only (ADV)
#     a (DET)
#     loose (ADJ)
#     network (NOUN)
#     of (ADP)
#
#  (SPACE)
#     volunteer (NOUN)
#     support (NOUN)
#     . (PUNCT)
#
#
#  (SPACE)
#     Project (PROPN)
#     Gutenberg (PROPN)
#     ™ (PROPN)
#     eBooks (PROPN)
#     are (AUX)
#     often (ADV)
#     created (VERB)
#     from (ADP)
#     several (ADJ)
#     printed (VERB)
#
#  (SPACE)
#     editions (NOUN)
#     , (PUNCT)
#     all (PRON)
#     of (ADP)
#     which (PRON)
#     are (AUX)
#     confirmed (VERB)
#     as (SCONJ)
#     not (PART)
#     protected (VERB)
#     by (ADP)
#     copyright (NOUN)
#     in (ADP)
#
#  (SPACE)
#     the (DET)
#     U.S. (PROPN)
#     unless (SCONJ)
#     a (DET)
#     copyright (NOUN)
#     notice (NOUN)
#     is (AUX)
#     included (VERB)
#     . (PUNCT)
#     Thus (ADV)
#     , (PUNCT)
#     we (PRON)
#     do (AUX)
#     not (PART)
#
#  (SPACE)
#     necessarily (ADV)
#     keep (VERB)
#     eBooks (PROPN)
#     in (ADP)
#     compliance (NOUN)
#     with (ADP)
#     any (DET)
#     particular (ADJ)
#     paper (NOUN)
#
#  (SPACE)
#     edition (NOUN)
#     . (PUNCT)
#
#
#  (SPACE)
#     Most (ADJ)
#     people (NOUN)
#     start (VERB)
#     at (ADP)
#     our (PRON)
#     website (NOUN)
#     which (PRON)
#     has (VERB)
#     the (DET)
#     main (ADJ)
#     PG (PROPN)
#     search (NOUN)
#
#  (SPACE)
#     facility (NOUN)
#     : (PUNCT)
#     www.gutenberg.org (NUM)
#     . (PUNCT)
#
#
#  (SPACE)
#     This (DET)
#     website (NOUN)
#     includes (VERB)
#     information (NOUN)
#     about (ADP)
#     Project (PROPN)
#     Gutenberg (PROPN)
#     ™ (X)
#     , (PUNCT)
#
#  (SPACE)
#     including (VERB)
#     how (SCONJ)
#     to (PART)
#     make (VERB)
#     donations (NOUN)
#     to (ADP)
#     the (DET)
#     Project (PROPN)
#     Gutenberg (PROPN)
#     Literary (PROPN)
#
#  (SPACE)
#     Archive (PROPN)
#     Foundation (PROPN)
#     , (PUNCT)
#     how (SCONJ)
#     to (PART)
#     help (VERB)
#     produce (VERB)
#     our (PRON)
#     new (ADJ)
#     eBooks (PROPN)
#     , (PUNCT)
#     and (CCONJ)
#     how (SCONJ)
#     to (PART)
#
#  (SPACE)
#     subscribe (VERB)
#     to (ADP)
#     our (PRON)
#     email (NOUN)
#     newsletter (NOUN)
#     to (PART)
#     hear (VERB)
#     about (ADP)
#     new (ADJ)
#     eBooks (PROPN)
#     . (PUNCT)

# %% [markdown]
# # Common Parts of Speech:
#
# Nouns: Common nouns in the text include "eBook," "use," "parts," "world," "cost," "restrictions," and "terms." Nouns are used to identify concepts, persons, places, and things.
#
# Nouns with specific titles or locales, such as "War of the Worlds," "Project Gutenberg," and "United States," are examples of proper nouns.
#
# Adpositions (Prepositions): Adpositions indicate the connections between nouns, pronouns, and phrases. Examples of such connections are "of," "for," "in," "at," "most," "of," "with," and "under."

# %% [markdown]
# # Uncommon Parts of Speech:
#
# Adjectives: Although they are less common than nouns, adjectives like "most" and "other" nevertheless function to alter or characterize nouns.

# %% [markdown]
# # Insights:
# Nouns such as "eBook", "use", "cost", and "restrictions" imply a conversation concerning the accessibility, application, and circumstances surrounding the eBook in question.
# Proper nouns, which anchor the text in specific contexts, imply precise references to organizations or titles, such as "War of the Worlds" and "Project Gutenberg."
# Adjectives such as "of", "for", "in", and "under" facilitate the establishment of links, such as possession, location, or condition, between various parts in the text.
# Adjectives like "most" and "other" provide the nouns they modify more specificity or comparison, which adds more background information.

# %% [markdown]
# ## Exercise 2
#
# Apply spaCy to extract the most meaningful content from your documents, considering options like excluding stop words or focusing on nouns (i.e. preprocessing and filtering).
#
# Perform a sentiment analysis on the refined data. Create visualization of your result.
#
# Summarize your results by explaining how sentiment changes across sections.

# %%
import requests
import spacy
import matplotlib.pyplot as plt

nlp = spacy.load("en_core_web_sm")

def preprocess_and_filter(text):
    doc = nlp(text)
    tokens = [token.text.lower() for token in doc if not token.is_stop and not token.is_punct]
    
    nouns = [token.text for token in doc if token.pos_ == "NOUN"]
    
    return tokens, nouns

url = "https://www.gutenberg.org/cache/epub/36/pg36.txt"
response = requests.get(url)
text = response.text

chunks = [chunk.strip() for chunk in text.split("\n\n") if chunk.strip()]

refined_data_tokens = []
refined_data_nouns = []
for chunk in chunks:
    tokens, nouns = preprocess_and_filter(chunk)
    refined_data_tokens.extend(tokens)
    refined_data_nouns.extend(nouns)

sentiment_scores = []
for chunk in chunks:
    doc = nlp(chunk)
    chunk_sentiment = sum([token.sentiment for token in doc]) / len(doc)
    sentiment_scores.append(chunk_sentiment)

positive_count = sum(1 for score in sentiment_scores if score > 0)
neutral_count = sum(1 for score in sentiment_scores if score == 0)
negative_count = sum(1 for score in sentiment_scores if score < 0)

labels = ['Positive', 'Neutral', 'Negative']
counts = [positive_count, neutral_count, negative_count]

plt.figure(figsize=(8, 6))
plt.bar(labels, counts, color=['green', 'purple', 'red'])
plt.title('Sentiment Analysis')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Insights
# 1.The sentiment analysis shows that there are emotional swings throughout the text, from happy peaks to depressing valleys.<br>
# 2.Positive sentiment peaks could represent moments of triumph or resolution, while negative sentiment falls could represent conflict or tension in the plot.<br>
# 3.Sentiment shifts are a reflection of the characters' emotional journeys; positive sentiment is associated with development or connection, and negative sentiment is associated with hardships or upheaval.
